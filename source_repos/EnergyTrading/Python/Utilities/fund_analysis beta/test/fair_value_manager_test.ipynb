# %%
from fund_analysis.fair_value_manager import FairValueManager
import pandas as pd
import datetime as dt
import os
import pickle

# %%
base_products = ['W_1', 'W_2', 'W_3', 'M_1', 'M_2', 'M_3', 'Q_1', 'Q_2', 'Q_3']
base_products = ['W_1', 'W_2', 'M_1', 'M_2']
market_list = ['de', 'fr']
delivery_dict = ['base', 'peak']

# Generate the combinations
products = []
markets = []
delivery = []

for product in base_products:
    for market in market_list:
        for delivery_option in delivery_dict:
            products.append(product)
            markets.append(market)
            delivery.append(delivery_option)

params_dict = {}

params_dict['product_list'] = products

params_dict['market_list'] = markets

params_dict['delivery_list'] = delivery 

params_dict['year_list'] = [None] * len(params_dict['market_list'])
params_dict['ns'] = 2
params_dict['cont'] = False


params_dict['sD'] = dt.datetime(2020,1,1)
params_dict['eD'] = pd.to_datetime(dt.datetime.today().date())
params_dict['eD'] = dt.datetime(2024,8,1)
params_dict['ns'] = 2
params_dict['cont'] = False

# %%
fcst_range = pd.date_range(start=pd.to_datetime('2024-07-08'),
                            end=pd.to_datetime('2024-07-08'))

# %%
fcst_range
# Out:
# DatetimeIndex(['2024-07-08'], dtype='datetime64[ns]', freq='D')

# %%
inst = FairValueManager(params_dict=params_dict,
                        fcst_range=fcst_range)

# %%
scen_dict = inst.get_fcst_curves()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scen_dict = inst.get_fcst_curves()
#
# File ~\Documents\Algo\Projects\fund_analysis\fund_analysis\fair_value_manager.py:112, in FairValueManager.get_fcst_curves(self, master_params_dict)
#     107             master_params_dict[predictor] = {'params': {'base_data': base_data,
#     108                                                 'params_dict': self.params_dict},
#     109                                             'scen_type': 'historical'}
#     110         elif predictor in ['Gas', 'Coal', 'Eua']:
#     111             master_params_dict[predictor] = {'params': {'base_data': base_data,
# --> 112                                                 'fuel_type': enums.fuel_names_map[predictor]},
#     113                                             'scen_type': 'defined'}
#     114 for predictor, params_dict in master_params_dict.items():
#     115     self.scenarios_inst(scenario_type=predictor,
#     116                         params=params_dict['params'])
#
# KeyError: 'Eua'

# %%
scen_dict
# Out:
# {Timestamp('2024-07-08 00:00:00'): {}}
