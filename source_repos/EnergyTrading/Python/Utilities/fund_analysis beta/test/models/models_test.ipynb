# %%
from fund_analysis.models.models import Model
from fund_analysis.utils.model_data_assembly import ModelDataAssembly
import pandas as pd
import datetime as dt
import os
import pickle

# %%
load_or_dump = 'load'

# Get the current working directory
current_dir = os.getcwd()

# Build the path to the 'data/test' folder
data_test_dir = r'C:\Users\krajcovic\Documents\Algo\Projects\fund_analysis\test\data'

file_path_processed = os.path.join(data_test_dir, 'processed_data.pkl')
with open(file_path_processed, 'rb') as f:
        processed_data = pickle.load(f)
        X_train, X_test, y_train, y_test = processed_data

# %%
inst = ModelDataAssembly({}, dt.datetime(2024,7,8))

# %%
X_train_scaled, X_test_scaled = inst.scale_data(X_train, X_test)

# %%
X_train_scaled
# Out:
# {'base':                      ResidualDemand_de  ResidualDemand_fr  Hydro_de  Hydro_fr  \
#  2020-01-02 00:00:00           0.375457           1.382661  0.375018  1.383989
#  2020-01-02 01:00:00           0.279013           1.194724  0.278500  1.195972
#  2020-01-02 02:00:00           0.208436           1.129714  0.207871  1.130931
#  2020-01-02 03:00:00           0.170027           0.968587  0.169434  0.969721
#  2020-01-02 04:00:00           0.201993           0.896767  0.201423  0.897861
#  ...                                ...                ...       ...       ...
#  2024-07-09 18:00:00                NaN                NaN  0.528548 -0.285330
#  2024-07-09 19:00:00                NaN                NaN  0.528548 -0.285330
#  2024-07-09 20:00:00                NaN                NaN  0.528548 -0.285330
#  2024-07-09 21:00:00                NaN                NaN  0.528548 -0.285330
#  2024-07-09 22:00:00                NaN                NaN  0.528548 -0.285330
#
#                       Hydro_at  ttf      api2       eua  de_Coal_de  \
#  2020-01-02 00:00:00 -0.563714  NaN -1.282658 -1.486445   -0.091529
#  2020-01-02 01:00:00 -0.563714  NaN -1.282658 -1.486445   -0.191797
#  2020-01-02 02:00:00 -0.563714  NaN -1.282658 -1.486445   -0.265162
#  2020-01-02 03:00:00 -0.563714  NaN -1.282658 -1.486445   -0.305084
#  2020-01-02 04:00:00 -0.563714  NaN -1.282658 -1.486445   -0.271859
#  ...                       ...  ...       ...       ...         ...
#  2024-07-09 18:00:00       NaN  NaN       NaN       NaN         NaN
#  2024-07-09 19:00:00       NaN  NaN       NaN       NaN         NaN
#  2024-07-09 20:00:00       NaN  NaN       NaN       NaN         NaN
#  2024-07-09 21:00:00       NaN  NaN       NaN       NaN         NaN
#  2024-07-09 22:00:00       NaN  NaN       NaN       NaN         NaN
#
#                       de_Coal_fr  ...  fr_Nuc_fr  fr_Oil_de  fr_Oil_fr  \
#  2020-01-02 00:00:00    0.334367  ...   0.691510   1.371456   1.376770
#  2020-01-02 01:00:00    0.237021  ...   0.434734   1.182205   1.186265
#  2020-01-02 02:00:00    0.165783  ...   0.339256   1.116733   1.120395
#  2020-01-02 03:00:00    0.127014  ...   0.110907   0.954436   0.957189
#  2020-01-02 04:00:00    0.159280  ...  -0.018041   0.882083   0.884466
#  ...                         ...  ...        ...        ...        ...
#  2024-07-09 18:00:00         NaN  ...        NaN        NaN        NaN
#  2024-07-09 19:00:00         NaN  ...        NaN        NaN        NaN
#  2024-07-09 20:00:00         NaN  ...        NaN        NaN        NaN
#  2024-07-09 21:00:00         NaN  ...        NaN        NaN        NaN
#  2024-07-09 22:00:00         NaN  ...        NaN        NaN        NaN
#
#                       fr_Pump_de  fr_Pump_fr  fr_Res_de  fr_RoR_de  gmc  \
#  2020-01-02 00:00:00    1.342824    1.335854   1.396380   1.367933  NaN
#  2020-01-02 01:00:00    1.148428    1.133472   1.208490   1.179874  NaN
#  2020-01-02 02:00:00    1.081306    1.063666   1.143588   1.114819  NaN
#  2020-01-02 03:00:00    0.915181    0.891068   0.982925   0.953570  NaN
#  2020-01-02 04:00:00    0.841228    0.814319   0.911401   0.881689  NaN
#  ...                         ...         ...        ...        ...  ...
#  2024-07-09 18:00:00         NaN         NaN        NaN        NaN  NaN
#  2024-07-09 19:00:00         NaN         NaN        NaN        NaN  NaN
#  2024-07-09 20:00:00         NaN         NaN        NaN        NaN  NaN
#  2024-07-09 21:00:00         NaN         NaN        NaN        NaN  NaN
#  2024-07-09 22:00:00         NaN         NaN        NaN        NaN  NaN
#
#                            cmc  mcr
#  2020-01-02 00:00:00 -1.411283  NaN
#  2020-01-02 01:00:00 -1.411283  NaN
#  2020-01-02 02:00:00 -1.411283  NaN
#  2020-01-02 03:00:00 -1.411283  NaN
#  2020-01-02 04:00:00 -1.411283  NaN
#  ...                       ...  ...
#  2024-07-09 18:00:00       NaN  NaN
#  2024-07-09 19:00:00       NaN  NaN
#  2024-07-09 20:00:00       NaN  NaN
#  2024-07-09 21:00:00       NaN  NaN
#  2024-07-09 22:00:00       NaN  NaN
#
#  [39623 rows x 41 columns]}

# %% [markdown]
# ## Test Model

# %%
model_params_dict = {'alpha': 0.010895398859824533, 'colsample_bytree': 0.9622126960415747,
            'gamma': 0.22653480769373827, 'lambda': 0.19084485197671305,
            'learning_rate': 0.02690767935041876, 'max_depth': 16, 'min_child_weight': 11,
            'n_estimators': 167, 'subsample': 0.2106044847212501,
            'nthread': -1}

# %%
model_inst = Model(X_train_scaled,
                    X_test_scaled,
                    y_train,
                    model_params_dict)

# %%
curve_pred = model_inst.model_predict_curve()

# %%
model_inst.x_test['base'].dropna()
# Out:
#                      ResidualDemand_de  ResidualDemand_fr  Hydro_de  Hydro_fr  \
# 2024-07-08 02:00:00          -0.079334          -0.956417 -0.080110 -0.956952
# 2024-07-08 03:00:00          -0.071694          -1.175126 -0.072465 -1.175928
# 2024-07-08 04:00:00          -0.007801          -1.242565 -0.008526 -1.243451
# 2024-07-08 05:00:00           0.081403          -1.024442  0.080744 -1.025059
# 2024-07-08 06:00:00           0.539810          -0.705828  0.539496 -0.706078
# ...                                ...                ...       ...       ...
# 2024-07-22 21:00:00           0.702312          -0.076828  0.702124 -0.076448
# 2024-07-22 22:00:00           0.519287           0.084164  0.518957  0.084684
# 2024-07-22 23:00:00           0.281543          -0.054178  0.281032 -0.053777
# 2024-07-23 00:00:00           0.202739          -0.385366  0.202170 -0.385278
# 2024-07-23 01:00:00           0.070832          -0.669724  0.070165 -0.669934
#
#                      Hydro_at       ttf      api2       eua  de_Coal_de  \
# 2024-07-08 02:00:00  1.932486 -0.073546 -0.105260  0.251235    0.354039
# 2024-07-08 03:00:00  1.932486 -0.073546 -0.105260  0.251235    0.362024
# 2024-07-08 04:00:00  1.932486 -0.073546 -0.105260  0.251235    0.428797
