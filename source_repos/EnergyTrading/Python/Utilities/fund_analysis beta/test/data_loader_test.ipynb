# %%
from fund_analysis.data_loader import DataLoader
import pandas as pd
import datetime as dt

# %%
sD = dt.datetime(2024,1,1)
eD = dt.datetime(2024,1,10)

dl_inst = DataLoader(sD, eD)

# fund = 'ResidualDemand'
# fcst_type = 'mid'
# ec_type = '00'

# df = dl_inst.get_raw_data(fcst_type=fcst_type,
#                             fund=fund,
#                             ec_type=ec_type)

# %%
sD = dt.datetime(2024,1,1)
eD = dt.datetime(2024,1,10)

dl_inst = DataLoader(sD, eD)

# %%
dl_inst.random_test()
# Out:
# succes
