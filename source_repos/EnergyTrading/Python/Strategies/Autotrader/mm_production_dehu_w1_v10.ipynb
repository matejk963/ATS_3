# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'test'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "mm_dehu_w1_v10"
caption = "MM DEHU W1 v10"
exchange = "TRAYPORT"
package_name="mm_strategy_v11"
instrument_ids = [ENUM.InstrumentID.DE_BASE,ENUM.InstrumentID.HU_BASE]
product_ids=['10000102_1186', '10000102_1186'] #, 
leg1_clip=1.0
leg2_clip=1.0
# broker_ids=["1441", "5", "8", "7"]
price_coeff = [1, 1]
broker_ids=["37", "38", "39"]
fix_margin=0.4
max_margin=0.4
market_depth=0.5
preferred_clips=1.0
max_clips=1.0
take_profit=0.31
stop_loss=0.28
hard_stop_loss=0.6
mtm_bool=True
quote_leg1=True
quote_leg2=True
quote_buy=True
quote_sell=False
model_type="EMA"
model_params=[
        12.1,
        0.025
    ]
eql_weight=1.0
eql_price=-19.5
mrg_weight=0.42
std_weight=1.18
ql_max=3.



config = {
     "internal_number": algo_id,
     "caption": caption,
     "exchange": exchange,
     "package_name": package_name,
     "instrument_ids": instrument_ids,
     "product_ids": product_ids,
     "leg1_clip": leg1_clip,
     "leg2_clip": leg2_clip,
     "price_coeff": price_coeff,
     "price_clips": price_coeff,
     "broker_ids": broker_ids,
     "fix_margin": fix_margin,
     "max_margin": max_margin,
     "preferred_clips": preferred_clips,
     "max_clips": max_clips,
     "take_profit": take_profit,
     "stop_loss": stop_loss,
     "hard_stop_loss": hard_stop_loss,
     "mtm_bool": mtm_bool,
     "quote_leg1": quote_leg1,
     "quote_leg2": quote_leg2,
     "quote_buy": quote_buy,
     "quote_sell": quote_sell,
     "model_type": model_type,
     "model_params": model_params,
     "eql_weight": eql_weight,
     "eql_price": eql_price,
     "mrg_weight": mrg_weight,
     "std_weight": std_weight,
     "ql_max": ql_max
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# 'bde00bdb-e3b4-4192-a37f-37faeb76d4dd'

# %%
cls.active_strategies()
# Out:
# []

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'mm_dehu_w1_v10'", 'status_code': 400}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000102_1186', '10000102_1186'],
#  'leg1_clip': 1.0,
#  'leg2_clip': 1.0,
#  'price_coeff': [1, 1],
#  'price_clips': [1, 1],
#  'broker_ids': ['37', '38', '39'],
#  'fix_margin': 0.4,
#  'max_margin': 0.4,
#  'preferred_clips': 1.0,
#  'max_clips': 1.0,
#  'take_profit': 0.31,
#  'stop_loss': 0.28,
#  'bo_max': 4.0,
#  'idle_thres': 0.03,
#  'market_depth': 0.3,
#  'hard_stop_loss': 0.6,
#  'mtm_bool': True,
#  'quote_leg1': True,
#  'quote_leg2': True,
#  'quote_buy': True,
#  'quote_sell': False,
#  'model_type': 'EMA',
#  'model_params': [12.1, 0.025],
#  'eql_weight': 1.0,
#  'eql_price': -19.5,
#  'mrg_weight': 0.42,
#  'std_weight': 1.18,
#  'ql_max': 3.0,
#  'internal_number': 'mm_dehu_w1_v10',
#  'caption': 'MM DEHU W1 v10',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10001126', '10001137'],
#  'package_name': 'mm_strategy_v11',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'mm_dehu_w1_v10',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 10,
#    '10000105': 10,
#    '10000106': 10},
#   'maximum_sales_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 10,
#    '10000105': 10,
#    '10000106': 10},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-08-13T09:37:31.038000'}
