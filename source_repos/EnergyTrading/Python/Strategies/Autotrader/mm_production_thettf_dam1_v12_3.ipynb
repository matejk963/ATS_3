# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "mm_de_m1q1_v_a1"
caption = "MM THETTF DA JUN25 v12_4"
exchange = "TRAYPORT"
package_name="market_making_v12_4"
instrument_ids = [ENUM.InstrumentID.THE_EEX,ENUM.InstrumentID.TTF_EEX]
product_ids=['10000302_2', '10000305_258'] #, 
leg1_clip=30.0
leg2_clip=1.0
# broker_ids=["1441", "5", "8", "7"]
price_coeff = [1, 1]
broker1_ids=["20"]
broker2_ids=["1441"]
fix_margin=0.2
max_margin=0.4
market_depth=0.5
preferred_clips=1.0
max_clips=1.0
take_profit=0.31
stop_loss=0.28
hard_stop_loss=0.6
mtm_bool=True
extended_logs=True
quote_leg1=True
quote_leg2=True
quote_buy=True
quote_sell=True
model_type="MSTD_x"
model_params=[
        13.9,
        0.025,
        0.1
    ]
eql_weight=0.0
eql_price=0.7
mrg_weight=0.24
std_weight=1.84
ql_max=.2



config = {
     "internal_number": algo_id,
     "caption": caption,
     "exchange": exchange,
     "package_name": package_name,
     "instrument_ids": instrument_ids,
     "product_ids": product_ids,
     "leg1_clip": leg1_clip,
     "leg2_clip": leg2_clip,
     "price_coeff": price_coeff,
     "broker1_ids": broker1_ids,
     "broker2_ids": broker2_ids,
     "fix_margin": fix_margin,
     "max_margin": max_margin,
     "market_depth": market_depth,
     "preferred_clips": preferred_clips,
     "max_clips": max_clips,
     "take_profit": take_profit,
     "stop_loss": stop_loss,
     "hard_stop_loss": hard_stop_loss,
     "mtm_bool": mtm_bool,
     "extended_logs": extended_logs,
     "quote_leg1": quote_leg1,
     "quote_leg2": quote_leg2,
     "quote_buy": quote_buy,
     "quote_sell": quote_sell,
     "model_type": model_type,
     "model_params": model_params,
     "eql_weight": eql_weight,
     "eql_price": eql_price,
     "mrg_weight": mrg_weight,
     "std_weight": std_weight,
     "ql_max": ql_max
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000302": 150,
                                   "10000305": 150},
        
        "minimum_sales_price": {"10000302": 2,
                                "10000305": 2},
        
        "maximum_purchase_volume": {"10000302": 60,
                                    "10000305": 10},
        
        
        
        "maximum_sales_volume": {   "10000302": 60, 
                                    "10000305": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '1fee2323-d883-4861-90c0-e5310d1744bf'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-cal-1',
#  'arbitrage-fr-qa',
#  'arbitrage-fr-qa-1',
#  'arbitrage-de-months',
#  'arbitrage-fr-months',
#  'arbitrage-fr-cal',
#  'arbitrage-de-weeks',
#  'arbitrage-fr-weeks',
#  'leadlag-dem1-dem2',
#  'arbitrage-de-weeks_1',
#  'baconv-dem2',
#  'spb-fr-m-1',
#  'spb-de-m-1',
#  'spb-de-m-2',
#  'spb-de-m-3']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000302_2', '10000305_258'],
#  'leg1_clip': 30.0,
#  'leg2_clip': 1.0,
#  'price_coeff': [1, 1],
#  'price_clips': [1, 1],
#  'broker1_ids': ['20'],
#  'broker2_ids': ['1441'],
#  'fix_margin': 0.2,
#  'max_margin': 0.4,
#  'preferred_clips': 1.0,
#  'max_clips': 1.0,
#  'take_profit': 0.31,
#  'stop_loss': 0.28,
#  'bo_max': 4.0,
#  'idle_thres': 0.03,
#  'market_depth': 0.5,
#  'hard_stop_loss': 0.6,
#  'mtm_bool': True,
#  'extended_logs': True,
#  'quote_leg1': True,
#  'quote_leg2': True,
#  'quote_buy': True,
#  'quote_sell': True,
#  'model_type': 'MSTD_x',
#  'model_params': [13.9, 0.025, 0.1],
#  'eql_weight': 0.0,
#  'eql_price': 0.7,
#  'mrg_weight': 0.24,
#  'std_weight': 1.84,
#  'ql_max': 0.2,
#  'internal_number': 'mm_de_m1q1_v_a1',
#  'caption': 'MM THETTF DA JUN25 v12_4',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10002148', '10002806'],
#  'package_name': 'market_making_v12_4',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'mm_de_m1q1_v_a1',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000302': 150,
#    '10000305': 150},
#   'maximum_purchase_volume': {'10000302': 60, '10000305': 10},
#   'maximum_sales_volume': {'10000302': 60, '10000305': 10},
#   'minimum_sales_price': {'10000302': 2, '10000305': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-05-09T07:54:03.521000'}
