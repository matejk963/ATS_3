# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "simple_strategy_python_test"
algo_caption = "SimpleStrategy_pythonTest"
exchange_id = "TRAYPORT"
sequence_id = ENUM.SequenceID.D
product_id = f"{sequence_id}_{TPData.calc_itemid('w', today)}"

instrument_id = ENUM.InstrumentID.DE_BASE_EEX
broker_id = "3"#ENUM.Broker._EEX

# Params
fix_margin = .5
leg1_clip = 1
leg2_clip = 1
preferred_clips = 1
max_clips = 1


config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": "simple_strategy",
    "instrument_ids": [instrument_id],
    "product_ids": [product_id],
    "fix_margin": fix_margin,
    "broker_id": broker_id,
    "leg1_clip": leg1_clip,
    "leg2_clip": leg2_clip,
    "max_clips": max_clips,
    "preferred_clips": preferred_clips
}

# %% [markdown]
# # Limits

# %%
limits ={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000101": 180},
        "minimum_sales_price": {"10000101": 50},
        "maximum_purchase_volume": {"10000101": 10},
        "maximum_sales_volume": {"10000101": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '288b6697-d9a0-434e-b47d-a495a820aecc'

# %%
cls.active_strategies()
# Out:
# []

# %%
cls.deactivate_strategy(algo_id)['active']
# Out:
# False

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'internal_number': 'simple_strategy_python_test',
#  'leg1_clip': 1.0,
#  'package_name': 'simple_strategy',
#  'exchange': 'TRAYPORT',
#  'leg2_clip': 1.0,
#  'fix_margin': 0.5,
#  'halted': False,
#  'caption': 'SimpleStrategy_pythonTest',
#  'halt_reason': '',
#  'broker_id': '14',
#  'product_ids': ['10000100_1145'],
#  'active': False,
#  'preferred_clips': 1.0,
#  'instrument_ids': ['10001075'],
#  'max_clips': 1.0}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'simple_strategy_python_test',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000101': 180},
#   'maximum_purchase_volume': {'10000101': 10},
#   'maximum_sales_volume': {'10000101': 10},
#   'minimum_sales_price': {'10000101': 50}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2023-12-06T10:55:05.107000'}
