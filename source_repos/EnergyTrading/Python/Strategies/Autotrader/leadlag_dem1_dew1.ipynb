# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "leadlag-dem1-dew1"
algo_caption = "LL DE Jul-24 vs DE Wk27-24"
exchange_id = "TRAYPORT"
package_name="leadlag_strategy_v1"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
lead_product_id='10000104_247'
lag_product_id='10000102_1175'
broker_id='1441'
lead_brokers_list=['1441']

max_secs_between_trades=10
cluster_trade_num_threshold=9
min_price_movement=0.2

take_profit=1.0
stop_loss=-0.4
trail_tp_bool=False
action_closing=False
trailing_tp_tau=10
ba_max=0.3

preferred_quantity=1
max_quantity=1

hard_stop_loss=2

ql_max=3

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "lead_product_id": lead_product_id,
    "lag_product_id": lag_product_id,
    "broker_id": broker_id,
    "lead_brokers_list": lead_brokers_list,

     "max_secs_between_trades": max_secs_between_trades,
     "cluster_trade_num_threshold": cluster_trade_num_threshold,
     "min_price_movement": min_price_movement,

    "take_profit": take_profit,
    "stop_loss":stop_loss,
    "trail_tp_bool": trail_tp_bool,
    "action_closing": action_closing,
    "trailing_tp_tau":trailing_tp_tau,
    "ba_max":ba_max,

    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,
    "hard_stop_loss": hard_stop_loss,

    "ql_max": ql_max

}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 5,
                                    "10000101": 5,
                                    "10000102": 5,
                                    "10000103": 5,
                                    "10000104": 5, 
                                    "10000105": 5, 
                                    "10000106": 5},
        
        
        
        "maximum_sales_volume": {   "10000100": 5, 
                                    "10000101": 5, 
                                    "10000102": 5, 
                                    "10000103": 5, 
                                    "10000104": 5, 
                                    "10000105": 5, 
                                    "10000106": 5}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '931e9657-ae70-4103-8537-cbfe67fe2b94'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-qa-2',
#  'arbitrage-de-qa-3',
#  'arbitrage-de-cal',
#  'arbitrage-de-cal-1',
#  'arbitrage-fr-qa',
#  'arbitrage-fr-qa-1',
#  'arbitrage-de-months',
#  'arbitrage-fr-months',
#  'arbitrage-fr-cal',
#  'arbitrage-es-qa',
#  'arbitrage-de-weeks',
#  'spbmark_m',
#  'arbitrage-fr-weeks']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'leadlag-dem1-dew1'", 'status_code': 400}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'lead_product_id': '10000104_247',
#  'lag_product_id': '10000102_1175',
#  'broker_id': '1441',
#  'lead_brokers_list': ['1441'],
#  'max_secs_between_trades': 10.0,
#  'cluster_trade_num_threshold': 9.0,
#  'min_price_movement': 0.2,
#  'take_profit': 1.0,
#  'stop_loss': -0.4,
#  'hard_stop_loss': 2.0,
#  'trail_tp_bool': False,
#  'trailing_tp_tau': 10.0,
#  'action_closing': False,
#  'ba_max': 0.3,
#  'preferred_quantity': 1.0,
#  'max_quantity': 1.0,
#  'ql_max': 3.0,
#  'internal_number': 'leadlag-dem1-dew1',
#  'caption': 'LL DE Jul-24 vs DE Wk27-24',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710', '10641710'],
#  'package_name': 'leadlag_strategy_v1',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'leadlag-dem1-dew1',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 5,
#    '10000105': 5,
#    '10000106': 5},
#   'maximum_sales_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 5,
#    '10000105': 5,
#    '10000106': 5},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-07-03T14:14:52.099000'}
