# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ENV

# %%
ENV = 'prod'
cls = TP_api(ENV)
cls.url, cls.token
# Out:
# ('https://etc-api-production.visotech.com/api',
#  '8a1b148c-de5f-4247-8fed-3949732dcd20')

# %% [markdown]
# Display available packages

# %%
cls.active_strategies()
# Out:
# []

# %%
cls.get_strategies()
# Out:
# [{'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.610000',
#   'caption': 'ARB DE Q325 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.468000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-qa',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.436000',
#   'caption': 'ARB DE Q425 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.467000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-qa-1',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.613000',
#   'caption': 'ARB DE Q126 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.468000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-qa-2',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.617000',
#   'caption': 'ARB DE Q226 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.470000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-qa-3',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.610000',
#   'caption': 'ARB DE CAL v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.632000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-cal',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.799000',
#   'caption': 'ARB DE CAL +1 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.635000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-cal-1',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.615000',
#   'caption': 'ARB FR Q325 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.633000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-qa',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:25:42.857000',
#   'caption': 'ARB FR Q425 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:25:43.401000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-qa-1',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.615000',
#   'caption': 'ARB DE Jun-25 and Jul-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:29.723000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-months',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.713000',
#   'caption': 'ARB FR Jun-25 and Jul-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.747000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-months',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v16_5',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB IT May-25 v16_5',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.040000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-it-months',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v16_9',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB IT Q325 v16_9',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.032000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-it-qa',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB FR CAL v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.031000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-cal',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB FR CAL +1 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.031000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-cal-1',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.454000',
#   'caption': 'ARB DE Wk20-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:29.721000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-weeks',
#   'message_counter': 1027693429},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T06:59:09.839000',
#   'caption': 'ARB FR Wk20-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:59:10.711000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-weeks',
#   'message_counter': 1027693465},
#  {'active': True,
#   'algorithm_package_name': 'leadlag_strategy_v5',
#   'alteration_time': '2025-05-05T10:28:29.798000',
#   'caption': 'LL DE Jun-25 vs DE Jul-25 v5',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.860000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'leadlag-dem1-dem2',
#   'message_counter': 1027694490},
#  {'active': True,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T10:28:29.617000',
#   'caption': 'ARB DE Wk21-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:29.724000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-weeks_1',
#   'message_counter': 1027693431},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB DE Aug-24 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.041000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-de-month_2',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v16_6',
#   'alteration_time': '2025-05-05T06:51:14.844000',
#   'caption': 'ARB DE FR Mar-25 v16_6',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:51:16.032000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-defr-months',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'baconv_strategy_v1_trade_sampling',
#   'alteration_time': '2025-05-05T10:28:29.610000',
#   'caption': 'BACON DE Jul-24',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:29.722000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'baconv-dem2',
#   'message_counter': 1027669979},
#  {'active': True,
#   'algorithm_package_name': 'spbmark_strategy_v09',
#   'alteration_time': '2025-05-05T10:28:29.615000',
#   'caption': 'SPB FR M1 v0.9',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.469000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'spb-fr-m-1',
#   'message_counter': 1027693435},
#  {'active': True,
#   'algorithm_package_name': 'spbmark_strategy_v09',
#   'alteration_time': '2025-05-05T10:28:29.613000',
#   'caption': 'SPB DE M1 v0.9',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:29.723000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'spb-de-m-1',
#   'message_counter': 1027693515},
#  {'active': True,
#   'algorithm_package_name': 'spbmark_strategy_v09',
#   'alteration_time': '2025-05-05T10:28:29.798000',
#   'caption': 'SPB DE M2 v0.9',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.749000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'spb-de-m-2',
#   'message_counter': 1027693493},
#  {'active': True,
#   'algorithm_package_name': 'spbmark_strategy_v09',
#   'alteration_time': '2025-05-05T10:28:29.705000',
#   'caption': 'SPB DE M3 v0.9',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T10:28:30.634000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'spb-de-m-3',
#   'message_counter': 1027669979},
#  {'active': False,
#   'algorithm_package_name': 'arbitrage_strategy_v17',
#   'alteration_time': '2025-05-05T06:59:21.754000',
#   'caption': 'ARB FR Wk21-25 v17',
#   'deleted': False,
#   'halt_reason': None,
#   'halted': False,
#   'insertion_time': '2025-05-05T06:59:21.848000',
#   'object_type': 'TradingPortfolio',
#   'trading_portfolio': 'arbitrage-fr-weeks-1'}]

# %%
print(*(f"{x['last_updated']} ---- {x['package_name']}" for x in cls.info_packages()), sep='\n')
# Out:
# 2024-07-09T10:52:14.459000Z ---- simple_strategy
# 2024-10-03T10:12:29.408000Z ---- spbmark_strategy
# 2024-10-31T10:39:12.304000Z ---- MarketMaking_a1
# 2024-12-05T12:28:27.910000Z ---- leadlag_strategy_v4
# 2025-01-14T15:49:08.742000Z ---- leadlag_strategy_v5
# 2025-02-04T08:33:54.202000Z ---- arbitrage_strategy_v16_5
# 2025-02-06T08:14:00.727000Z ---- arbitrage_strategy_v16_6
# 2025-02-20T13:42:54.178000Z ---- leadlag_strategy_v6
# 2025-03-07T13:29:35.824000Z ---- spbmark_strategy_v08
# 2025-03-26T10:03:14.095000Z ---- spbmark_strategy_v09
# 2025-03-26T14:59:26.832000Z ---- baconv_strategy_v1_trade_sampling
# 2025-03-31T11:20:07.676000Z ---- market_making_v12_3
# 2025-04-01T08:46:31.135000Z ---- arbitrage_strategy_v16_8
# 2025-04-01T11:03:19.402000Z ---- arbitrage_strategy_v16_9
# 2025-04-03T11:40:56.149000Z ---- arbitrage_strategy_v16_9_1
# 2025-04-29T13:31:56.654000Z ---- arbitrage_strategy_v17

# %% [markdown]
# Open explorer

# %%
import os

# Define the directory you want to open
folder_path = os.path.expanduser('S:\Algo\Production_strategies')  # This will open the user's home directory

# Use os.startfile to open the folder in Windows Explorer
try:
    os.startfile(folder_path)
except AttributeError:
    print("os.startfile is only available on Windows.")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# Upload package

# %%
file_path = r"S:\Algo\Production_strategies\Market_Making\v12\market_making_v12_4.zip"
cls.upload_packages(file_path)
# Out:
# <Response [201]>

# %% [markdown]
# Delete package

# %%
algo_id = 'mm_test'

# %%
cls.deactivate_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'mm_test'", 'status_code': 400}

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'mm_test'", 'status_code': 400}

# %%
package_name = "market_making_v12_3"
cls.delete_package(package_name)
# Out:
# <Response [200]>
