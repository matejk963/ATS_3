# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'test'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()


broker_eex = "1262"
broker_id1 = "36"  #BRO1
broker_id2 = "37"  #BRO2
broker_id3 = "38"  #BRO3
broker_id4 = "39"  #BRO4

algo_id = "mm_test"
caption = "MM TEST REF v12_3"
exchange = "TRAYPORT"
package_name="market_making_v12_3"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
product_ids=['10000104_264', '10000105_95'] #, 
leg1_clip=3
leg2_clip=1
price_coeff = [1, 1]
broker_ids=[broker_id1, broker_id2]
fix_margin=0.2
max_margin=0.4
market_depth=0.5
preferred_clips=1.0
max_clips=2.0
take_profit=0.43
stop_loss=0.43
hard_stop_loss=1.0
mtm_bool=True
extended_logs=True
quote_leg1=True
quote_leg2=False
quote_buy=True
quote_sell=True
model_type="MID"
model_params=[
        0.5,
        0.025
    ]
eql_weight=0.0
eql_price=4.5
mrg_weight=0.4
std_weight=2.05
ql_max=0.5



config = {
     "internal_number": algo_id,
     "caption": caption,
     "exchange": exchange,
     "package_name": package_name,
     "instrument_ids": instrument_ids,
     "product_ids": product_ids,
     "leg1_clip": leg1_clip,
     "leg2_clip": leg2_clip,
     "price_coeff": price_coeff,
     "broker_ids": broker_ids,
     "fix_margin": fix_margin,
     "max_margin": max_margin,
     "market_depth": market_depth,
     "preferred_clips": preferred_clips,
     "max_clips": max_clips,
     "take_profit": take_profit,
     "stop_loss": stop_loss,
     "hard_stop_loss": hard_stop_loss,
     "mtm_bool": mtm_bool,
     "extended_logs": extended_logs,
     "quote_leg1": quote_leg1,
     "quote_leg2": quote_leg2,
     "quote_buy": quote_buy,
     "quote_sell": quote_sell,
     "model_type": model_type,
     "model_params": model_params,
     "eql_weight": eql_weight,
     "eql_price": eql_price,
     "mrg_weight": mrg_weight,
     "std_weight": std_weight,
     "ql_max": ql_max
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 20,
                                    "10000101": 20,
                                    "10000102": 20,
                                    "10000103": 20,
                                    "10000104": 20, 
                                    "10000105": 20, 
                                    "10000106": 20},
        
        
        
        "maximum_sales_volume": {   "10000100": 20, 
                                    "10000101": 20, 
                                    "10000102": 20, 
                                    "10000103": 20, 
                                    "10000104": 20, 
                                    "10000105": 20, 
                                    "10000106": 20}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# 'a7d8d280-c286-49ef-be70-d91a50f08449'

# %%
cls.active_strategies()
# Out:
# []

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000104_264', '10000105_95'],
#  'leg1_clip': 3.0,
#  'leg2_clip': 1.0,
#  'price_coeff': [1, 1],
#  'price_clips': [1, 1],
#  'broker_ids': ['36', '37'],
#  'fix_margin': 0.2,
#  'max_margin': 0.4,
#  'preferred_clips': 1.0,
#  'max_clips': 2.0,
#  'take_profit': 0.43,
#  'stop_loss': 0.43,
#  'bo_max': 4.0,
#  'idle_thres': 0.03,
#  'market_depth': 0.5,
#  'hard_stop_loss': 1.0,
#  'mtm_bool': True,
#  'extended_logs': True,
#  'quote_leg1': True,
#  'quote_leg2': False,
#  'quote_buy': True,
#  'quote_sell': True,
#  'model_type': 'MID',
#  'model_params': [0.5, 0.025],
#  'eql_weight': 0.0,
#  'eql_price': 4.5,
#  'mrg_weight': 0.4,
#  'std_weight': 2.05,
#  'ql_max': 0.5,
#  'internal_number': 'mm_test',
#  'caption': 'MM TEST REF v12_3',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710', '10641710'],
#  'package_name': 'market_making_v12_3',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'mm_test',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 20,
#    '10000101': 20,
#    '10000102': 20,
#    '10000103': 20,
#    '10000104': 20,
#    '10000105': 20,
#    '10000106': 20},
#   'maximum_sales_volume': {'10000100': 20,
#    '10000101': 20,
#    '10000102': 20,
#    '10000103': 20,
#    '10000104': 20,
#    '10000105': 20,
#    '10000106': 20},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-03-27T16:39:15.811000'}
