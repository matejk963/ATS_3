# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "baconv-dem2"
algo_caption = "BACON DE Jul-24"
exchange_id = "TRAYPORT"
package_name="baconv_strategy_v1_trade_sampling"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX]
product_id='10000104_259'
broker_id='1441'

take_profit=2
stop_loss=-1
aggloss_thres=0.04

ba_conv_large_threshold=0.03
ba_conv_small_threshold=0.01
ba_conv_volatility_threshold=0.05
ba_conv_ba_threshold=0.09

MACD_long_threshold = 0.0
MACD_short_threshold = -0.05
minimum_intensity=0.5

burnout_period=60
stop_profit = 0.3
makeagg_ratio = 0.6
trail_stop=0.8

ba_max=0.3

preferred_quantity=0
max_quantity=0

hard_stop_loss=1

ql_max=3

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "product_id": product_id,
    "broker_id": broker_id,
    
    "ba_conv_large_threshold":ba_conv_large_threshold,
    "ba_conv_small_threshold":ba_conv_small_threshold,
    "ba_conv_volatility_threshold":ba_conv_volatility_threshold,
    "ba_conv_ba_threshold":ba_conv_ba_threshold,

    "MACD_long_threshold": MACD_long_threshold,
    "MACD_short_threshold": MACD_short_threshold,
    "minimum_intensity": minimum_intensity,
    
    "burnout_period": burnout_period,
    "stop_profit": stop_profit,
    "makeagg_ratio": makeagg_ratio,
    "trail_stop": trail_stop,

    "take_profit": take_profit,
    "stop_loss":stop_loss,
    "aggloss_thres": aggloss_thres,

    "ba_max":ba_max,

    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,
    "hard_stop_loss": hard_stop_loss,

    "ql_max": ql_max

}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 5,
                                    "10000101": 5,
                                    "10000102": 5,
                                    "10000103": 5,
                                    "10000104": 1, 
                                    "10000105": 5, 
                                    "10000106": 5},
        
        
        
        "maximum_sales_volume": {   "10000100": 5, 
                                    "10000101": 5, 
                                    "10000102": 5, 
                                    "10000103": 5, 
                                    "10000104": 1, 
                                    "10000105": 5, 
                                    "10000106": 5}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '833343bb-1bba-40db-be85-eeed9eb8912f'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-weeks', 'arbitrage-de-weeks_1']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'baconv-dem2'", 'status_code': 400}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_id': '10000104_259',
#  'broker_id': '1441',
#  'ba_conv_large_threshold': 0.03,
#  'ba_conv_small_threshold': 0.01,
#  'ba_conv_volatility_threshold': 0.05,
#  'ba_conv_ba_threshold': 0.09,
#  'MACD_long_threshold': 0.0,
#  'MACD_short_threshold': -0.05,
#  'minimum_intensity': 0.5,
#  'take_profit': 2.0,
#  'stop_loss': -1.0,
#  'aggloss_thres': 0.04,
#  'burnout_period': 60.0,
#  'stop_profit': 0.3,
#  'makeagg_ratio': 0.6,
#  'trail_stop': 0.8,
#  'ba_max': 0.3,
#  'preferred_quantity': 0.0,
#  'max_quantity': 0.0,
#  'hard_stop_loss': 1.0,
#  'ql_max': 3.0,
#  'internal_number': 'baconv-dem2',
#  'caption': 'BACON DE Jul-24',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710'],
#  'package_name': 'baconv_strategy_v1_trade_sampling',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'baconv-dem2',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 1,
#    '10000105': 5,
#    '10000106': 5},
#   'maximum_sales_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 1,
#    '10000105': 5,
#    '10000106': 5},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-05-02T07:11:40.206000'}
