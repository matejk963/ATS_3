# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "arbitrage-de-dec"
algo_caption = "ARB DE Jan-25 v14"
exchange_id = "TRAYPORT"
package_name="arbitrage_strategy_v14"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
product_ids = ['10000104_253']#f"{sequence_id}_{TPData.calc_itemid('', today)}"

broker_id1 = "1441" #ENUM.Broker._EEX
broker_id2 = "7"  #ENUM.Broker._TFS
broker_id3 = "5"  #ENUM.Broker._SPEC
broker_id4 = "8"  #ENUM.Broker._42FS
broker_id5 = "2"  #ENUM.Broker._GFI
broker_id6 = "4"  #ENUM.Broker._ICAP
broker_id7 = "3"  #ENUM.Broker._GRFN


opt_margin = .09
min_margin = .08
max_margin = .15
margin_for_closing=0.25
closing_in_profit_flag=0.0
preferred_quantity=1
max_quantity=1

stop_loss=2
idle_thres=0.03
hard_stop_loss=2

advanced_making=True
market_volume_check_flag=1
ql_max=1

cross_arb=True
cross_arb_margin_min=0.07
cross_arb_margin_max=0.15
min_time_cross=3.

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "product_ids": product_ids,
    "broker_ids": [broker_id1, broker_id5, broker_id2,  broker_id4, broker_id6, broker_id7, broker_id3],

    "opt_margin": opt_margin,
    "min_margin": min_margin,
    "max_margin": max_margin,
    "margin_for_closing" : margin_for_closing,
    "closing_in_profit_flag" : closing_in_profit_flag,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,

    "stop_loss": stop_loss,
    "idle_thres": idle_thres,
    "hard_stop_loss": hard_stop_loss,
    
    "advanced_making": advanced_making,
    "market_volume_check_flag":market_volume_check_flag,
    "ql_max": ql_max,

    "cross_arb": cross_arb,
    "cross_arb_margin_min": cross_arb_margin_min,
    "cross_arb_margin_max": cross_arb_margin_max,
    "min_time_cross": min_time_cross
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 20, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 20, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '3365737f-4d55-4671-98a0-2a1d1ead34ea'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-qa-2',
#  'arbitrage-de-qa-3',
#  'arbitrage-de-cal',
#  'arbitrage-de-cal-1',
#  'arbitrage-fr-qa',
#  'arbitrage-fr-qa-1',
#  'arbitrage-de-weeks',
#  'arbitrage-fr-weeks',
#  'spbmark_m_2',
#  'spbmark_m_1',
#  'leadlag-dem1-dem2']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000104_253'],
#  'broker_ids': ['1441', '2', '7', '8', '4', '3', '5'],
#  'opt_margin': 0.09,
#  'min_margin': 0.08,
#  'max_margin': 0.15,
#  'margin_for_closing': 0.25,
#  'closing_in_profit_flag': 0.0,
#  'preferred_quantity': 1.0,
#  'max_quantity': 1.0,
#  'stop_loss': 2.0,
#  'idle_thres': 0.03,
#  'hard_stop_loss': 2.0,
#  'market_volume_check_flag': 1.0,
#  'ql_max': 1.0,
#  'advanced_making': True,
#  'cross_arb': True,
#  'cross_arb_margin_min': 0.07,
#  'cross_arb_margin_max': 0.15,
#  'min_time_cross': 3.0,
#  'internal_number': 'arbitrage-de-dec',
#  'caption': 'ARB DE Jan-25 v14',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710', '10641710'],
#  'package_name': 'arbitrage_strategy_v14',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'arbitrage-de-dec',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 20,
#    '10000105': 10,
#    '10000106': 10},
#   'maximum_sales_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 20,
#    '10000105': 10,
#    '10000106': 10},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-10-03T10:47:24.654000'}
