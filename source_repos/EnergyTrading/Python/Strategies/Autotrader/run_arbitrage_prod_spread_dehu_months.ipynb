# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "arbitrage-dehu-months"
algo_caption = "ARB DE HU Aug-25 v17"
exchange_id = "TRAYPORT"
package_name="arbitrage_strategy_spread_v1"
instrument_ids = [ENUM.InstrumentID.DE_HU_BASE_EEX, ENUM.InstrumentID.DE_BASE_EEX, ENUM.InstrumentID.HU_BASE_EEX]
product_ids = ['10000104_260', '10000104_260', '10000104_260']#f"{sequence_id}_{TPData.calc_itemid('', today)}"

broker_id1 = "1441" #ENUM.Broker._EEX
broker_id2 = "7"  #ENUM.Broker._TFS
broker_id3 = "5"  #ENUM.Broker._SPEC
broker_id4 = "8"  #ENUM.Broker._42FS
broker_id5 = "2"  #ENUM.Broker._GFI
broker_id6 = "4"  #ENUM.Broker._ICAP
broker_id7 = "3"  #ENUM.Broker._GRFN
broker_id8 = "10"  #ENUM.Broker._BGC

broker_ids_main = [broker_id2, broker_id3, broker_id4, broker_id5, broker_id6, broker_id7, broker_id8]
exchange_broker_ids = [broker_id1]


opt_margin = .12
min_margin = .12
max_margin = .30
margin_for_closing=0.15
closing_in_profit_flag=1.0
preferred_quantity=1
max_quantity=1

stop_loss=2
idle_thres=0.03
hard_stop_loss=2

public_update = False
advanced_making=True
broker_making=True
market_volume_check_flag=0
ql_max=0.3

cons_making = False
cons_making_aux = False
cons_margin = 0.05
cons_min_level = 0.1
verbose = False

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "product_ids": product_ids,

    
    "broker_ids": [broker_id1, broker_id5, broker_id2,  broker_id4, broker_id6, broker_id7, broker_id3, broker_id8],
    "exchange_broker_ids": exchange_broker_ids,
    "broker_ids_main": broker_ids_main,

    "opt_margin": opt_margin,
    "min_margin": min_margin,
    "max_margin": max_margin,
    "margin_for_closing" : margin_for_closing,
    "closing_in_profit_flag" : closing_in_profit_flag,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,

    "stop_loss": stop_loss,
    "idle_thres": idle_thres,
    "hard_stop_loss": hard_stop_loss,
    
    "public_update": public_update,
    "advanced_making": advanced_making,
    "broker_making": broker_making,
    "market_volume_check_flag":market_volume_check_flag,
    "ql_max": ql_max,

    "cons_making": cons_making,
    "cons_making_aux": cons_making_aux,
    "cons_margin": cons_margin,
    "cons_min_level": cons_min_level,
    "verbose": verbose
    
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000104": -1},
        
        "minimum_sales_price": {"10000104": -30},
        
        "maximum_purchase_volume": {"10000104": 1},

        "maximum_sales_volume": {"10000104": 1}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '93d804b1-38cf-43bc-a2c7-aad93c527c94'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-months',
#  'arbitrage-fr-months',
#  'arbitrage-de-weeks',
#  'arbitrage-de-weeks_1']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000104_260', '10000104_260', '10000104_260'],
#  'broker_ids': ['1441', '2', '7', '8', '4', '3', '5', '10'],
#  'exchange_broker_ids': ['1441'],
#  'broker_ids_main': ['7', '5', '8', '2', '4', '3', '10'],
#  'opt_margin': 0.12,
#  'min_margin': 0.12,
#  'max_margin': 0.3,
#  'min_margin_aux': 0.1,
#  'margin_for_closing': 0.15,
#  'closing_in_profit_flag': 1.0,
#  'preferred_quantity': 1.0,
#  'max_quantity': 1.0,
#  'stop_loss': 2.0,
#  'idle_thres': 0.03,
#  'hard_stop_loss': 2.0,
#  'market_volume_check_flag': 0.0,
#  'ql_max': 0.3,
#  'public_update': False,
#  'advanced_making': True,
#  'broker_making': True,
#  'maximum_neg_buyback': 5,
#  'cons_making': False,
#  'cons_making_aux': False,
#  'cons_margin': 0.05,
#  'cons_min_level': 0.1,
#  'verbose': False,
#  'internal_number': 'arbitrage-dehu-months',
#  'caption': 'ARB DE HU Aug-25 v17',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10642360', '10641710', '10011036'],
# ...

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'arbitrage-dehu-months',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000104': -1},
#   'maximum_purchase_volume': {'10000104': 1},
#   'maximum_sales_volume': {'10000104': 1},
#   'minimum_sales_price': {'10000104': -30}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-07-18T08:17:07.543000'}
