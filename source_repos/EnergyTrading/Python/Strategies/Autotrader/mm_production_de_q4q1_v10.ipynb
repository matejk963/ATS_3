# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "mm_de_q4q1_v10"
caption = "MM DE Q4Q1 v10"
exchange = "TRAYPORT"
package_name="mm_strategy_v10"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
product_ids=['10000105_84', '10000105_85'] #, 
leg1_clip=1.0
leg2_clip=1.0
broker_ids=["1441", "5", "8", "7"]
fix_margin=0.4
max_margin=0.4
market_depth=0.5
preferred_clips=1.0
max_clips=1.0
take_profit=0.31
stop_loss=0.28
hard_stop_loss=0.6
mtm_bool=True
quote_leg1=True
quote_leg2=True
quote_buy=True
quote_sell=False
model_type="MSTD_x"
model_params=[
        12.1,
        0.025
    ]
eql_weight=0.0
eql_price=4.5
mrg_weight=0.42
std_weight=1.18
ql_max=3.



config = {
     "internal_number": algo_id,
     "caption": caption,
     "exchange": exchange,
     "package_name": package_name,
     "instrument_ids": instrument_ids,
     "product_ids": product_ids,
     "leg1_clip": leg1_clip,
     "leg2_clip": leg2_clip,
     "broker_ids": broker_ids,
     "fix_margin": fix_margin,
     "max_margin": max_margin,
     "preferred_clips": preferred_clips,
     "max_clips": max_clips,
     "take_profit": take_profit,
     "stop_loss": stop_loss,
     "hard_stop_loss": hard_stop_loss,
     "mtm_bool": mtm_bool,
     "quote_leg1": quote_leg1,
     "quote_leg2": quote_leg2,
     "quote_buy": quote_buy,
     "quote_sell": quote_sell,
     "model_type": model_type,
     "model_params": model_params,
     "eql_weight": eql_weight,
     "eql_price": eql_price,
     "mrg_weight": mrg_weight,
     "std_weight": std_weight,
     "ql_max": ql_max
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '45f91edc-e28f-4ca5-910a-b87cc8cc8e52'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-qa-2',
#  'arbitrage-de-qa-3',
#  'arbitrage-de-cal',
#  'arbitrage-de-cal-1',
#  'arbitrage-fr-qa',
#  'arbitrage-fr-qa-1',
#  'arbitrage-de-months',
#  'arbitrage-fr-months',
#  'arbitrage-it-months',
#  'arbitrage-de-peaks-months',
#  'arbitrage-it-qa-1',
#  'mm_de_m23_v10']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'status_code': 400, 'message': "Invalid strategy_id: 'mm_de_q4q1_v10'"}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'package_name': 'mm_strategy_v10',
#  'model_params': [12.1, 0.025],
#  'eql_price': 4.5,
#  'mtm_bool': True,
#  'fix_margin': 0.4,
#  'hard_stop_loss': 0.6,
#  'price_clips': [1, 1],
#  'market_depth': 0.3,
#  'instrument_ids': ['10641710', '10641710'],
#  'eql_weight': 0.0,
#  'max_margin': 0.4,
#  'leg1_clip': 1.0,
#  'quote_sell': False,
#  'stop_loss': 0.28,
#  'halt_reason': '',
#  'preferred_clips': 1.0,
#  'bo_max': 4.0,
#  'ql_max': 3.0,
#  'max_clips': 1.0,
#  'internal_number': 'mm_de_q4q1_v10',
#  'exchange': 'TRAYPORT',
#  'take_profit': 0.31,
#  'halted': False,
#  'quote_buy': True,
#  'active': False,
#  'std_weight': 1.18,
#  'quote_leg1': True,
#  'leg2_clip': 1.0,
#  'quote_leg2': True,
#  'broker_ids': ['1441', '5', '8', '7'],
#  'caption': 'MM DE Q4Q1 v10',
#  'product_ids': ['10000105_84', '10000105_85'],
#  'model_type': 'MSTD_x',
#  'mrg_weight': 0.42,
#  'idle_thres': 0.03}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'mm_de_q4q1_v10',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000102': 150,
#    '10000103': 150,
#    '10000100': 150,
#    '10000101': 150,
#    '10000106': 150,
#    '10000104': 150,
#    '10000105': 150},
#   'maximum_purchase_volume': {'10000102': 10,
#    '10000103': 10,
#    '10000100': 10,
#    '10000101': 10,
#    '10000106': 10,
#    '10000104': 10,
#    '10000105': 10},
#   'maximum_sales_volume': {'10000102': 10,
#    '10000103': 10,
#    '10000100': 10,
#    '10000101': 10,
#    '10000106': 10,
#    '10000104': 10,
#    '10000105': 10},
#   'minimum_sales_price': {'10000102': 2,
#    '10000103': 2,
#    '10000100': 2,
#    '10000101': 2,
#    '10000106': 2,
#    '10000104': 2,
#    '10000105': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-03-21T08:54:43.671000'}
