# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'test'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "mm_de_w12_v_a1"
caption = "MM DE W1W2 v a1"
exchange = "TRAYPORT"
package_name="MarketMaking_a1"
# Prod
#instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
# Test
instrument_ids = [ENUM.InstrumentID.DE_BASE,ENUM.InstrumentID.DE_BASE]
product_ids=['10000102_1189', '10000102_1190'] #Week 39v40, 
leg1_clip=1.0
leg2_clip=1.0
#broker_ids=["1441", "5", "7", "2", "4"]
broker_ids = ['37', '36']
fix_margin=0.2
preferred_clips=25
max_clips=75
#take_profit=0.43
stop_loss=1
hard_stop_loss=1.0
mtm_bool=True
model_type="MSTD_x"
model_params=[
        100,
        0.024,
        2
        ]
eql_weight=0.0
eql_price=4.5
#mrg_weight=0.4
std_weight=1
price_coeff = [1,1]
quote_leg1 = True
quote_leg2 = True
quote_buy = True
quote_sell = True
extended_logs = True




config = {
     "internal_number": algo_id,
     "caption": caption,
     "exchange": exchange,
     "package_name": package_name,
     "instrument_ids": instrument_ids,
     "product_ids": product_ids,
     "leg1_clip": leg1_clip,
     "leg2_clip": leg2_clip,
     "broker_ids": broker_ids,
     "fix_margin": fix_margin,
     "preferred_clips": preferred_clips,
     "max_clips": max_clips,
     "stop_loss": stop_loss,
     "hard_stop_loss": hard_stop_loss,
     "mtm_bool": mtm_bool,
     "model_type": model_type,
     "model_params": model_params,
     "eql_weight": eql_weight,
     "eql_price": eql_price,
     "std_weight": std_weight,
    "price_coeff": price_coeff,
    "quote_leg1": quote_leg1,
    "quote_leg2": quote_leg2,
    "quote_buy": quote_buy,
    "quote_sell": quote_sell,
    "extended_logs": extended_logs
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 100,
                                    "10000101": 100,
                                    "10000102": 100,
                                    "10000103": 100,
                                    "10000104": 100, 
                                    "10000105": 100, 
                                    "10000106": 100},
        
        
        
        "maximum_sales_volume": {   "10000100": 100, 
                                    "10000101": 100, 
                                    "10000102": 100, 
                                    "10000103": 100, 
                                    "10000104": 100, 
                                    "10000105": 100, 
                                    "10000106": 100}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# 'c2a12d99-a6f4-4d66-bd32-a8f0ed52ce8b'

# %%
cls.active_strategies()
# Out:
# []

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'mm_de_w12_v_a1'", 'status_code': 400}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000102_1189', '10000102_1190'],
#  'leg1_clip': 1.0,
#  'leg2_clip': 1.0,
#  'price_coeff': [1, 1],
#  'price_clips': [1, 1],
#  'broker_ids': ['37', '36'],
#  'fix_margin': 0.2,
#  'preferred_clips': 25.0,
#  'max_clips': 75.0,
#  'stop_loss': 1.0,
#  'bo_max': 4.0,
#  'idle_thres': 0.03,
#  'market_depth': 0.3,
#  'hard_stop_loss': 1.0,
#  'mtm_bool': True,
#  'quote_leg1': True,
#  'quote_leg2': True,
#  'quote_buy': True,
#  'quote_sell': True,
#  'model_type': 'MSTD_x',
#  'model_params': [100, 0.024, 2],
#  'eql_weight': 0.0,
#  'eql_price': 4.5,
#  'std_weight': 1.0,
#  'ql_max': 3.0,
#  'extended_logs': True,
#  'internal_number': 'mm_de_w12_v_a1',
#  'caption': 'MM DE W1W2 v a1',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10001126', '10001126'],
#  'package_name': 'MarketMaking_a1',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'mm_de_w12_v_a1',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 100,
#    '10000101': 100,
#    '10000102': 100,
#    '10000103': 100,
#    '10000104': 100,
#    '10000105': 100,
#    '10000106': 100},
#   'maximum_sales_volume': {'10000100': 100,
#    '10000101': 100,
#    '10000102': 100,
#    '10000103': 100,
#    '10000104': 100,
#    '10000105': 100,
#    '10000106': 100},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-10-04T07:28:38.409000'}

# %%
print(datetime.now())
# Out:
# 2024-10-04 09:28:38.654140
