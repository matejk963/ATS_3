# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "leadlag-dem1-dem2"
algo_caption = "LL DE Oct-24 vs DE Nov-24"
exchange_id = "TRAYPORT"
package_name="leadlag_strategy_v2"
instrument_ids = [ENUM.InstrumentID.DE_BASE_EEX,ENUM.InstrumentID.DE_BASE_EEX]
lead_product_id='10000104_250'
lag_product_id='10000104_251'
broker_id='1441'
lead_brokers_list=['1441']

take_profit=1.5
stop_loss=-0.5

MACD_long_threshold = 0.0119
MACD_short_threshold = -0.0839
price_diff_long_threshold = 0.05
price_diff_short_threshold = -0.05

reg_model_coef1 = 0
reg_model_coef2 = 0.8661

burnout_period=60
stop_profit = 0.3
makeagg_ratio = 0.6

ba_max=0.3

preferred_quantity=1
max_quantity=0

hard_stop_loss=1

ql_max=3

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "lead_product_id": lead_product_id,
    "lag_product_id": lag_product_id,
    "broker_id": broker_id,
    "lead_brokers_list": lead_brokers_list,

    "MACD_long_threshold": MACD_long_threshold,
    "MACD_short_threshold": MACD_short_threshold,
    "price_diff_long_threshold": price_diff_long_threshold,   
    "price_diff_short_threshold": price_diff_short_threshold,
    
    "reg_model_coef1": reg_model_coef1,
    "reg_model_coef2": reg_model_coef2,
    
    "burnout_period": burnout_period,
    "stop_profit": stop_profit,
    "makeagg_ratio": makeagg_ratio,

    "take_profit": take_profit,
    "stop_loss":stop_loss,

    "ba_max":ba_max,

    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,
    "hard_stop_loss": hard_stop_loss,

    "ql_max": ql_max

}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 5,
                                    "10000101": 5,
                                    "10000102": 5,
                                    "10000103": 5,
                                    "10000104": 1, 
                                    "10000105": 5, 
                                    "10000106": 5},
        
        
        
        "maximum_sales_volume": {   "10000100": 5, 
                                    "10000101": 5, 
                                    "10000102": 5, 
                                    "10000103": 5, 
                                    "10000104": 1, 
                                    "10000105": 5, 
                                    "10000106": 5}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# 'ff40ee78-92aa-48e5-97a4-0cae4064cede'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-cal',
#  'arbitrage-de-months',
#  'arbitrage-de-weeks',
#  'spbmark_m_2',
#  'spbmark_m_1',
#  'leadlag-dem1-dem2',
#  'mm_de_w12_v_a1']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'lead_product_id': '10000104_250',
#  'lag_product_id': '10000104_251',
#  'broker_id': '1441',
#  'lead_brokers_list': ['1441'],
#  'MACD_long_threshold': 0.0119,
#  'MACD_short_threshold': -0.0839,
#  'price_diff_long_threshold': 0.05,
#  'price_diff_short_threshold': -0.05,
#  'reg_model_coef1': 0.0,
#  'reg_model_coef2': 0.8661,
#  'take_profit': 1.5,
#  'stop_loss': -0.5,
#  'hard_stop_loss': 1.0,
#  'burnout_period': 60.0,
#  'stop_profit': 0.3,
#  'makeagg_ratio': 0.6,
#  'ba_max': 0.3,
#  'preferred_quantity': 1.0,
#  'max_quantity': 0.0,
#  'ql_max': 3.0,
#  'internal_number': 'leadlag-dem1-dem2',
#  'caption': 'LL DE Oct-24 vs DE Nov-24',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710', '10641710'],
#  'package_name': 'leadlag_strategy_v2',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'leadlag-dem1-dem2',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 1,
#    '10000105': 5,
#    '10000106': 5},
#   'maximum_sales_volume': {'10000100': 5,
#    '10000101': 5,
#    '10000102': 5,
#    '10000103': 5,
#    '10000104': 1,
#    '10000105': 5,
#    '10000106': 5},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-09-19T07:01:22.474000'}
