# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'test'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "arbitrage-de-fr-may"
algo_caption = "ARB DE FR Dec-25 v1"
exchange_id = "TRAYPORT"
package_name="arbitrage_strategy_spread_v1"
instrument_ids = ["10641750", "10641710", "10001075"]
product_ids = ['10000104_264', '10000104_264', '10000104_264']#f"{sequence_id}_{TPData.calc_itemid('', today)}"

broker_eex = "27"
broker_id1 = "36"  #BRO1
broker_id2 = "37"  #BRO2
broker_id3 = "38"  #BRO3
broker_id4 = "39"  #BRO4


opt_margin = .10
min_margin = .07
max_margin = .15
margin_for_closing=0.25
closing_in_profit_flag=0.0
preferred_quantity=5
max_quantity=5

stop_loss=2
idle_thres=0.03
hard_stop_loss=2

public_update = False
advanced_making=True
broker_making=True
market_volume_check_flag=0
ql_max=0.3

cons_making = False
cons_making_aux = False
cons_margin = 0.05
cons_min_level = 0.1
verbose = True

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": instrument_ids,
    "product_ids": product_ids,
    
    "broker_ids": [broker_id1, broker_id2, broker_id3, broker_id4],
    "exchange_broker_ids": [broker_eex],
    "broker_ids_main": [broker_id2, broker_id3, broker_id4],

    "opt_margin": opt_margin,
    "min_margin": min_margin,
    "max_margin": max_margin,
    "margin_for_closing" : margin_for_closing,
    "closing_in_profit_flag" : closing_in_profit_flag,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,

    "stop_loss": stop_loss,
    "idle_thres": idle_thres,
    "hard_stop_loss": hard_stop_loss,
    
    "public_update": public_update,
    "advanced_making": advanced_making,
    "broker_making": broker_making,
    "market_volume_check_flag":market_volume_check_flag,
    "ql_max": ql_max,

    "cons_making": cons_making,
    "cons_making_aux": cons_making_aux,
    "cons_margin": cons_margin,
    "cons_min_level": cons_min_level,
    "verbose": verbose

}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 30,
                                   "10000101": 30,
                                   "10000102": 30,
                                   "10000103": 30,
                                   "10000104": 30, 
                                   "10000105": 30, 
                                   "10000106": 30},
        
        "minimum_sales_price": {"10000100": -30,
                                "10000101": -30,
                                "10000102": -30,
                                "10000103": -30,
                                "10000104": -30, 
                                "10000105": -30, 
                                "10000106": -30},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 20, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 20, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '84d802e8-7dfb-4989-9402-8c43c8cb7acd'

# %%
cls.active_strategies()
# Out:
# []

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000104_264', '10000104_264', '10000104_264'],
#  'broker_ids': ['36', '37', '38', '39'],
#  'exchange_broker_ids': ['27'],
#  'broker_ids_main': ['37', '38', '39'],
#  'opt_margin': 0.1,
#  'min_margin': 0.07,
#  'max_margin': 0.15,
#  'min_margin_aux': 0.1,
#  'margin_for_closing': 0.25,
#  'closing_in_profit_flag': 0.0,
#  'preferred_quantity': 5.0,
#  'max_quantity': 5.0,
#  'stop_loss': 2.0,
#  'idle_thres': 0.03,
#  'hard_stop_loss': 2.0,
#  'market_volume_check_flag': 0.0,
#  'ql_max': 0.3,
#  'public_update': False,
#  'advanced_making': True,
#  'broker_making': True,
#  'maximum_neg_buyback': 5,
#  'cons_making': False,
#  'cons_making_aux': False,
#  'cons_margin': 0.05,
#  'cons_min_level': 0.1,
#  'verbose': True,
#  'internal_number': 'arbitrage-de-fr-may',
#  'caption': 'ARB DE FR Dec-25 v1',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641750', '10641710', '10001075'],
#  'package_name': 'arbitrage_strategy_spread_v1',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'arbitrage-de-fr-may',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 30,
#    '10000101': 30,
#    '10000102': 30,
#    '10000103': 30,
#    '10000104': 30,
#    '10000105': 30,
#    '10000106': 30},
#   'maximum_purchase_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 20,
#    '10000105': 10,
#    '10000106': 10},
#   'maximum_sales_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 20,
#    '10000105': 10,
#    '10000106': 10},
#   'minimum_sales_price': {'10000100': -30,
#    '10000101': -30,
#    '10000102': -30,
#    '10000103': -30,
#    '10000104': -30,
#    '10000105': -30,
#    '10000106': -30}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-07-18T07:38:33.850000'}
