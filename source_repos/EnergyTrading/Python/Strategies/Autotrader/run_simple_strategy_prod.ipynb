# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "simple_strategy"
algo_caption = "SimpleStrategy"
exchange_id = "TRAYPORT"
product_id = '10000104_253'#f"{sequence_id}_{TPData.calc_itemid('', today)}"

instrument_id = ENUM.InstrumentID.IT_BASE_EEX
broker_id = "10"#ENUM.Broker._BGC

# Params
fix_margin = .5
preferred_quantity = 1
max_quantity = 1


config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": "simple_strategy",
    "instrument_ids": [instrument_id],
    "product_ids": [product_id],
    "fix_margin": fix_margin,
    "broker_id": broker_id,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity
}

# %% [markdown]
# # Limits

# %%
limits ={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000104": 150},
        "minimum_sales_price": {"10000104": 100},
        "maximum_purchase_volume": {"10000104": 5},
        "maximum_sales_volume": {"10000104": 5}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# 'de147938-315b-4773-be03-870e2314a662'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-cal-1',
#  'arbitrage-de-months',
#  'arbitrage-de-weeks',
#  'spbmark_m_2',
#  'spbmark_m_1',
#  'leadlag-dem1-dem2',
#  'arbitrage-de-weeks_1',
#  'spbmark_m_3',
#  'arbitrage-de-month_2',
#  'arbitrage-de-weekend']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# {'message': "Invalid strategy_id: 'simple_strategy'", 'status_code': 400}

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000104_253'],
#  'broker_id': '10',
#  'fix_margin': 0.5,
#  'preferred_quantity': 1.0,
#  'max_quantity': 1.0,
#  'internal_number': 'simple_strategy',
#  'caption': 'SimpleStrategy',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10100480'],
#  'package_name': 'simple_strategy',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'simple_strategy',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000104': 150},
#   'maximum_purchase_volume': {'10000104': 5},
#   'maximum_sales_volume': {'10000104': 5},
#   'minimum_sales_price': {'10000104': 100}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2024-12-02T08:32:36.035000'}
