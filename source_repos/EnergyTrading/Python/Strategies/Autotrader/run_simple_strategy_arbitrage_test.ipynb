# %%
from TP_api import TP_api
from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'test'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "synthetic-order-arbitrage"
algo_caption = "synthetic_order_arbitrage_DE_Base_202311"
exchange_id = "TRAYPORT"
package_name="arbitrage_strategy"
instrument_id = ENUM.InstrumentID.DE_BASE_EEX
sequence_id = ENUM.SequenceID.M
product_id = '10000104_248'#f"{sequence_id}_{TPData.calc_itemid('', today)}"

broker_id1 = "36" #ENUM.Broker._EEX
broker_id2 = "37"  #ENUM.Broker._TFS

fix_margin = .5
preferred_quantity=1
max_quantity=1

stop_loss=2
idle_thres=0.03
hard_stop_loss=2

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": [instrument_id, instrument_id],
    "product_ids": [product_id],
    "broker_ids": [broker_id1, broker_id2],

    "fix_margin": fix_margin,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,

    "stop_loss": stop_loss,
    "idle_thres": idle_thres,
    "hard_stop_loss": hard_stop_loss
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '39359bf5-8659-468c-8a3a-12bbc5869aaa'

# %%
cls.active_strategies()
# Out:
# []

# %%
cls.deactivate_strategy(algo_id)['active']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cls.deactivate_strategy(algo_id)['active']
#
# TypeError: string indices must be integers, not 'str'

# %%
cls.delete_strategy(algo_id)

# %%
result = cls.create_strategy(config)
result
# Out:
# {'hard_stop_loss': 2.0,
#  'package_name': 'arbitrage_strategy',
#  'stop_loss': 2.0,
#  'max_quantity': 1.0,
#  'exchange': 'TRAYPORT',
#  'fix_margin': 0.5,
#  'internal_number': 'synthetic-order-arbitrage',
#  'broker_ids': ['36', '37'],
#  'preferred_quantity': 1.0,
#  'halted': False,
#  'caption': 'synthetic_order_arbitrage_DE_Base_202311',
#  'halt_reason': '',
#  'product_ids': ['10000104_248'],
#  'active': False,
#  'instrument_ids': ['10641710', '10641710'],
#  'idle_thres': 0.03}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'synthetic-order-arbitrage',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000102': 150,
#    '10000103': 150,
#    '10000100': 150,
#    '10000101': 150,
#    '10000106': 150,
#    '10000104': 150,
#    '10000105': 150},
#   'maximum_purchase_volume': {'10000102': 10,
#    '10000103': 10,
#    '10000100': 10,
#    '10000101': 10,
#    '10000106': 10,
#    '10000104': 10,
#    '10000105': 10},
#   'maximum_sales_volume': {'10000102': 10,
#    '10000103': 10,
#    '10000100': 10,
#    '10000101': 10,
#    '10000106': 10,
#    '10000104': 10,
#    '10000105': 10},
#   'minimum_sales_price': {'10000102': 2,
#    '10000103': 2,
#    '10000100': 2,
#    '10000101': 2,
#    '10000106': 2,
#    '10000104': 2,
#    '10000105': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
# ...
