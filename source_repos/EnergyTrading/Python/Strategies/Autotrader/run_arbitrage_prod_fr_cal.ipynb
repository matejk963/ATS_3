# %%
from TP_api import TP_api
#from Database.TPData import TPData
from datetime import datetime
import enumerate as ENUM

# %% [markdown]
# ## Enviroment

# %%
ENV = 'prod'

# %% [markdown]
# # Strategy config

# %%
today = datetime.now()

algo_id = "arbitrage-fr-cal"
algo_caption = "ARB FR CAL v17"
exchange_id = "TRAYPORT"
package_name="arbitrage_strategy_v17"
instrument_id = "10001075"
sequence_id = ENUM.SequenceID.M
product_id = '10000106_23'#f"{sequence_id}_{TPData.calc_itemid('', today)}"

broker_id1 = "1441" #ENUM.Broker._EEX
broker_id2 = "7"  #ENUM.Broker._TFS
broker_id3 = "5"  #ENUM.Broker._SPEC
broker_id4 = "8"  #ENUM.Broker._42FS
broker_id5 = "2"  #ENUM.Broker._GFI
broker_id6 = "4"  #ENUM.Broker._ICAP
broker_id7 = "3"  #ENUM.Broker._GRFN
broker_id8 = "10"  #ENUM.Broker._BGC



opt_margin = .07
min_margin = .07
max_margin = .20
margin_for_closing=0.25
closing_in_profit_flag=0.0
preferred_quantity=1
max_quantity=1

stop_loss=2
idle_thres=0.03
hard_stop_loss=2

public_update = False
advanced_making=True
broker_making=False
market_volume_check_flag=1.0
ql_max=0.2

cross_arb=False
cross_arb_margin_min=0.07
cross_arb_margin_max=0.15
min_time_cross=10.

cons_making = False
cons_margin = 0.10
verbose = False

config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": [instrument_id, instrument_id],
    "product_ids": [product_id],
    "broker_ids": [broker_id1, broker_id2, broker_id4],#[broker_id1, broker_id5, broker_id2,  broker_id4, broker_id6, broker_id7, broker_id8, broker_id3],

    "opt_margin": opt_margin,
    "min_margin": min_margin,
    "max_margin": max_margin,
    "margin_for_closing" : margin_for_closing,
    "closing_in_profit_flag" : closing_in_profit_flag,
    "preferred_quantity": preferred_quantity,
    "max_quantity": max_quantity,

    "stop_loss": stop_loss,
    "idle_thres": idle_thres,
    "hard_stop_loss": hard_stop_loss,

    "public_update": public_update,
    "advanced_making": advanced_making,
    "broker_making": broker_making,
    "market_volume_check_flag":market_volume_check_flag,
    "ql_max": ql_max,

    "cross_arb": cross_arb,
    "cross_arb_margin_min": cross_arb_margin_min,
    "cross_arb_margin_max": cross_arb_margin_max,
    "min_time_cross": min_time_cross,

    "cons_making": cons_making,
    "cons_margin": cons_margin,
    "verbose": verbose
}

# %% [markdown]
# # Limits

# %%
limits={
    "limits_per_sequence":
    {
        "maximum_purchase_price": {"10000100": 150,
                                   "10000101": 150,
                                   "10000102": 150,
                                   "10000103": 150,
                                   "10000104": 150, 
                                   "10000105": 150, 
                                   "10000106": 150},
        
        "minimum_sales_price": {"10000100": 2,
                                "10000101": 2,
                                "10000102": 2,
                                "10000103": 2,
                                "10000104": 2, 
                                "10000105": 2, 
                                "10000106": 2},
        
        "maximum_purchase_volume": {"10000100": 10,
                                    "10000101": 10,
                                    "10000102": 10,
                                    "10000103": 10,
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10},
        
        
        
        "maximum_sales_volume": {   "10000100": 10, 
                                    "10000101": 10, 
                                    "10000102": 10, 
                                    "10000103": 10, 
                                    "10000104": 10, 
                                    "10000105": 10, 
                                    "10000106": 10}
    }
}

# %%
cls = TP_api(ENV)
cls.token
# Out:
# '800af773-14e1-4541-b31c-bbb5b0974298'

# %%
cls.active_strategies()
# Out:
# ['arbitrage-de-qa',
#  'arbitrage-de-qa-1',
#  'arbitrage-de-months',
#  'arbitrage-fr-months',
#  'arbitrage-de-weeks',
#  'arbitrage-fr-weeks',
#  'arbitrage-de-weeks_1',
#  'spb-fr-m-1',
#  'spb-de-m-1',
#  'spb-de-m-2',
#  'spb-de-m-3',
#  'spb-fr-m-2']

# %%
if algo_id in cls.active_strategies():
    cls.deactivate_strategy(algo_id)['active']

# %%
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
result = cls.create_strategy(config)
result
# Out:
# {'product_ids': ['10000106_23'],
#  'broker_ids': ['1441', '2', '7', '8', '4', '3', '10', '5'],
#  'opt_margin': 0.07,
#  'min_margin': 0.07,
#  'max_margin': 0.2,
#  'margin_for_closing': 0.25,
#  'closing_in_profit_flag': 0.0,
#  'preferred_quantity': 1.0,
#  'max_quantity': 1.0,
#  'stop_loss': 2.0,
#  'idle_thres': 0.03,
#  'hard_stop_loss': 2.0,
#  'market_volume_check_flag': 1.0,
#  'ql_max': 0.2,
#  'public_update': False,
#  'advanced_making': True,
#  'broker_making': False,
#  'cross_arb': False,
#  'cross_arb_margin_min': 0.07,
#  'cross_arb_margin_max': 0.15,
#  'min_time_cross': 10.0,
#  'maximum_neg_buyback': 5,
#  'cons_making': False,
#  'cons_margin': 0.1,
#  'verbose': False,
#  'internal_number': 'arbitrage-fr-cal',
#  'caption': 'ARB FR CAL v17',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10001075', '10001075'],
#  'package_name': 'arbitrage_strategy_v17',
#  'halted': False,
#  'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'arbitrage-fr-cal',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 150,
#    '10000101': 150,
#    '10000102': 150,
#    '10000103': 150,
#    '10000104': 150,
#    '10000105': 150,
#    '10000106': 150},
#   'maximum_purchase_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 10,
#    '10000105': 10,
#    '10000106': 10},
#   'maximum_sales_volume': {'10000100': 10,
#    '10000101': 10,
#    '10000102': 10,
#    '10000103': 10,
#    '10000104': 10,
#    '10000105': 10,
#    '10000106': 10},
#   'minimum_sales_price': {'10000100': 2,
#    '10000101': 2,
#    '10000102': 2,
#    '10000103': 2,
#    '10000104': 2,
#    '10000105': 2,
#    '10000106': 2}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-05-20T07:11:47.648000'}
