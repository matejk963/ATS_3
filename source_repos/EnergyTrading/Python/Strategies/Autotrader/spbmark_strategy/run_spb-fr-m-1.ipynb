# %%
from datetime import datetime, timedelta
import os
import numpy as np
import pandas as pd

import Strategies.Autotrader.enumerate as ENUM
from Utilities.Storage import get_curr_storage_path
from Strategies.Autotrader.TP_api import TP_api

# %% [markdown]
# ### Enviroment

# %%
ENV = 'prod'
cls = TP_api(ENV)
cls.token
# Out:
# '5a0d65ae-fd8d-45cf-a5fe-8ae63933528a'

# %% [markdown]
# ### Strategy config

# %% [markdown]
# #### Calculate product id for desired month product

# %%
month_item_id_to_month = lambda x: (x-241)%12+1

# %%
def month_to_item_id(month):
    return 241 + (month - 1) + 12 * ((256 - 241) // 12)

# %%
from SynthSpread.spreadviewer_class import SpreadSingle
today = datetime.now().date() + timedelta(days=1)
dates = pd.date_range(today, today, freq='B')
spread_class = SpreadSingle(['fr'], ['m'], [1], [], ['eex'])
product_date = spread_class.product_dates(dates, 2, tn_bool=True)
item_id = month_to_item_id(product_date[0][0].month)
item_id
# Out:
# 259

# %%
_STORAGE = get_curr_storage_path()
DIR_PATH  = 'strategies_deploy_data/spb-fr-m-1/' + str(today) + '/'
try:
    os.makedirs(_STORAGE + DIR_PATH)
except FileExistsError:
    print(_STORAGE + DIR_PATH, 'already exists')

# %% [markdown]
# Calibration result
#
#     5_0.05_200_5
#     clustersize = 5
#     fees = 0.05
#     top_k = 200
#     train days = 5

# %%
_CLUSTER_SIZE = 5
_FEES = 0.05
_TOP_K = 200
_TRAIN_DAYS = 5

# %%
today = datetime.now().date() + timedelta(days=1)
delta = np.busday_offset(today, -_TRAIN_DAYS)
_START_DATE = str(delta)
delta = np.busday_offset(today, -1)
_END_DATE = str(delta)
print(_START_DATE, _END_DATE)
# Out:
# 2025-04-28 2025-05-02

# %%
_ROOT = os.getcwd().split('Strategies')[0]
reg_data_file = _ROOT + 'Strategies/Sparsity_strategy/data_factory_reg.py'

# %%
reg_data_file
# Out:
# 'c:\\Users\\algouser\\Documents\\GitHub\\EnergyTrading\\Python\\Strategies/Sparsity_strategy/data_factory_reg.py'

# %%
# !python {reg_data_file} --instrument frm1 --start_date {_START_DATE} --end_date {_END_DATE} --directory_path {DIR_PATH}
# Out:
# Dates out [datetime.datetime(2024, 1, 1, 0, 0), datetime.datetime(2024, 1, 11, 0, 0), datetime.datetime(2024, 1, 12, 0, 0), datetime.datetime(2024, 1, 15, 0, 0), datetime.datetime(2024, 1, 16, 0, 0), datetime.datetime(2024, 1, 17, 0, 0), datetime.datetime(2024, 1, 18, 0, 0), datetime.datetime(2024, 1, 19, 0, 0), datetime.datetime(2024, 1, 22, 0, 0), datetime.datetime(2024, 1, 23, 0, 0), datetime.datetime(2024, 3, 13, 0, 0), datetime.datetime(2024, 3, 14, 0, 0), datetime.datetime(2024, 3, 15, 0, 0), datetime.datetime(2024, 3, 18, 0, 0), datetime.datetime(2024, 3, 29, 0, 0), datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 4, 9, 0, 0), datetime.datetime(2024, 4, 10, 0, 0), datetime.datetime(2024, 5, 1, 0, 0), datetime.datetime(2024, 5, 22, 0, 0), datetime.datetime(2024, 5, 23, 0, 0), datetime.datetime(2024, 5, 24, 0, 0), datetime.datetime(2024, 5, 27, 0, 0), datetime.datetime(2024, 6, 3, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 23, 0, 0), datetime.datetime(2025, 1, 29, 0, 0), datetime.datetime(2025, 2, 26, 0, 0), datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 2, 28, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 21, 0, 0), datetime.datetime(2025, 5, 1, 0, 0)]
# Connected to the database oracle
# Disconnected from the database oracle
# 25-04-28 Loading OrderBook 0...
# OrderBook 0 created in 1 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-29 Loading OrderBook 0...
# OrderBook 0 created in 1 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-30 Loading OrderBook 0...
# OrderBook 0 created in 2 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-02 Loading OrderBook 0...
# OrderBook 0 created in 0 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# single positional indexer is out-of-bounds
# ['lvl_dist', 'trd_price', 'trd_gap', 'trd_side', 'last_trade_margin']
# C:\Users\algouser\Documents\GitHub\EnergyTrading\Python\Strategies\Sparse_momentum\ob_attributes.py:1161: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['last_trd_p'].ffill(inplace=True)

# %%
cache_returns_file = _ROOT + 'Strategies/Sparsity_strategy/test_cache_returns.py'

# %%
# !python {cache_returns_file} --instrument frm1 --directory_path {DIR_PATH}
# Out:
#    processing combination 0 / 84
#    processing combination 1 / 84
#    processing combination 2 / 84
#    processing combination 3 / 84
#    processing combination 4 / 84
#    processing combination 5 / 84
#    processing combination 6 / 84
#    processing combination 7 / 84
#    processing combination 8 / 84
#    processing combination 9 / 84
#    processing combination 10 / 84
#    processing combination 11 / 84
#    processing combination 12 / 84
#    processing combination 13 / 84
#    processing combination 14 / 84
#    processing combination 15 / 84
#    processing combination 16 / 84
#    processing combination 17 / 84
#    processing combination 18 / 84
#    processing combination 19 / 84
#    processing combination 20 / 84
#    processing combination 21 / 84
#    processing combination 22 / 84
#    processing combination 23 / 84
#    processing combination 24 / 84
#    processing combination 25 / 84
#    processing combination 26 / 84
#    processing combination 27 / 84
#    processing combination 28 / 84
#    processing combination 29 / 84
#    processing combination 30 / 84
#    processing combination 31 / 84
#    processing combination 32 / 84
#    processing combination 33 / 84
#    processing combination 34 / 84
#    processing combination 35 / 84
#    processing combination 36 / 84
#    processing combination 37 / 84
#    processing combination 38 / 84
#    processing combination 39 / 84
#    processing combination 40 / 84
#    processing combination 41 / 84
#    processing combination 42 / 84
#    processing combination 43 / 84
#    processing combination 44 / 84
#    processing combination 45 / 84
#    processing combination 46 / 84
#    processing combination 47 / 84
#    processing combination 48 / 84
#    processing combination 49 / 84
#    processing combination 50 / 84
#    processing combination 51 / 84
#    processing combination 52 / 84
#    processing combination 53 / 84
#    processing combination 54 / 84
#    processing combination 55 / 84
#    processing combination 56 / 84
#    processing combination 57 / 84
#    processing combination 58 / 84
#    processing combination 59 / 84
#    processing combination 60 / 84
#    processing combination 61 / 84
#    processing combination 62 / 84
#    processing combination 63 / 84
#    processing combination 64 / 84
#    processing combination 65 / 84
#    processing combination 66 / 84
#    processing combination 67 / 84
#    processing combination 68 / 84
#    processing combination 69 / 84
#    processing combination 70 / 84
#    processing combination 71 / 84
#    processing combination 72 / 84
#    processing combination 73 / 84
#    processing combination 74 / 84
#    processing combination 75 / 84
#    processing combination 76 / 84
#    processing combination 77 / 84
#    processing combination 78 / 84
#    processing combination 79 / 84
#    processing combination 80 / 84
#    processing combination 81 / 84
#    processing combination 82 / 84
#    processing combination 83 / 84
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.02s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.67s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.16s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.39s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:11<00:22, 11.06s/days]
# Processing: 100%|██████████| 3/3 [00:11<00:00,  3.69s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:14,  7.01s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.34s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:22<00:45, 22.52s/days]
# Processing: 100%|██████████| 3/3 [00:22<00:00,  7.51s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:20<00:41, 20.91s/days]
# Processing: 100%|██████████| 3/3 [00:20<00:00,  6.97s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:30, 15.07s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.02s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:15,  7.64s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.55s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.55s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.52s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.74s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.91s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:31, 15.74s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.25s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.53s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.51s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.91s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.64s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:30, 15.06s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.02s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:33, 16.82s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.61s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:32, 16.20s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.40s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:10<00:20, 10.37s/days]
# Processing: 100%|██████████| 3/3 [00:10<00:00,  3.46s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.25s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.42s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:18,  9.45s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.15s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:23<00:46, 23.08s/days]
# Processing: 100%|██████████| 3/3 [00:23<00:00,  7.69s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.04s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.68s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.44s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.48s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:15,  7.87s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.62s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:12<00:24, 12.29s/days]
# Processing: 100%|██████████| 3/3 [00:12<00:00,  4.10s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.93s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.98s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:33, 16.59s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.53s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:12<00:25, 12.69s/days]
# Processing: 100%|██████████| 3/3 [00:12<00:00,  4.23s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:10<00:20, 10.12s/days]
# Processing: 100%|██████████| 3/3 [00:10<00:00,  3.37s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:35, 17.96s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.99s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.24s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.75s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:32, 16.01s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.34s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.51s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.50s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:11<00:23, 11.94s/days]
# Processing: 100%|██████████| 3/3 [00:11<00:00,  3.98s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:18,  9.20s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.07s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:28, 14.30s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.77s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.56s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.85s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:22<00:45, 22.62s/days]
# Processing: 100%|██████████| 3/3 [00:22<00:00,  7.54s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:18,  9.13s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.04s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.57s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.52s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:30, 15.37s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.12s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:19<00:38, 19.08s/days]
# Processing: 100%|██████████| 3/3 [00:19<00:00,  6.36s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.01s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.34s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:19,  9.93s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.31s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:18,  9.33s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.11s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:33, 16.79s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.60s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:19<00:39, 19.81s/days]
# Processing: 100%|██████████| 3/3 [00:19<00:00,  6.60s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.27s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.42s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.79s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.93s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:08<00:17,  8.60s/days]
# Processing: 100%|██████████| 3/3 [00:08<00:00,  2.87s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:18<00:36, 18.12s/days]
# Processing: 100%|██████████| 3/3 [00:18<00:00,  6.04s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.62s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.54s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.01s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.34s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:27, 13.51s/days]
# Processing:  67%|██████▋   | 2/3 [00:13<00:05,  5.75s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  3.62s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.97s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.13s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.38s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.63s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.88s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:22<00:45, 22.66s/days]
# Processing: 100%|██████████| 3/3 [00:22<00:00,  7.55s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:10<00:20, 10.12s/days]
# Processing: 100%|██████████| 3/3 [00:10<00:00,  3.37s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:12<00:24, 12.36s/days]
# Processing: 100%|██████████| 3/3 [00:12<00:00,  4.12s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:08<00:16,  8.10s/days]
# Processing: 100%|██████████| 3/3 [00:08<00:00,  2.70s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:15,  7.57s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.52s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:33, 16.70s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.57s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:19<00:38, 19.29s/days]
# Processing: 100%|██████████| 3/3 [00:19<00:00,  6.43s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.33s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.78s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.39s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.46s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:10<00:20, 10.10s/days]
# Processing: 100%|██████████| 3/3 [00:10<00:00,  3.37s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:19,  9.73s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.24s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:14,  7.04s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.35s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:24<00:49, 24.74s/days]
# Processing: 100%|██████████| 3/3 [00:24<00:00,  8.25s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:16<00:33, 16.98s/days]
# Processing: 100%|██████████| 3/3 [00:16<00:00,  5.66s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.39s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.80s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:09<00:19,  9.84s/days]
# Processing: 100%|██████████| 3/3 [00:09<00:00,  3.28s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:07<00:15,  7.88s/days]
# Processing: 100%|██████████| 3/3 [00:07<00:00,  2.63s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:14<00:29, 14.52s/days]
# Processing: 100%|██████████| 3/3 [00:14<00:00,  4.84s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.41s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.47s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:17<00:34, 17.50s/days]
# Processing: 100%|██████████| 3/3 [00:17<00:00,  5.83s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:13<00:26, 13.41s/days]
# Processing: 100%|██████████| 3/3 [00:13<00:00,  4.47s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:30, 15.11s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.04s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:18<00:37, 18.57s/days]
# Processing: 100%|██████████| 3/3 [00:18<00:00,  6.19s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:18<00:37, 18.98s/days]
# Processing: 100%|██████████| 3/3 [00:18<00:00,  6.33s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:12<00:25, 12.55s/days]
# Processing: 100%|██████████| 3/3 [00:12<00:00,  4.18s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:12<00:25, 12.63s/days]
# Processing: 100%|██████████| 3/3 [00:12<00:00,  4.21s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:08<00:16,  8.31s/days]
# Processing: 100%|██████████| 3/3 [00:08<00:00,  2.77s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:18<00:36, 18.24s/days]
# Processing: 100%|██████████| 3/3 [00:18<00:00,  6.08s/days]
#
# Processing:   0%|          | 0/3 [00:00<?, ?days/s]
# Processing:  33%|███▎      | 1/3 [00:15<00:31, 15.60s/days]
# Processing: 100%|██████████| 3/3 [00:15<00:00,  5.20s/days]

# %% [markdown]
#         '--instrument': {'type': str, 'default': 'dem1'},
#         '--top_k': {'type': int, 'default': 1000},
#         '--fees': {'type': float, 'default': 0.12},
#         '--train_days': {'type': int, 'default': 5},
#         '--cluster_size': {'type': int, 'default': 10},
#         '--directory_path': {'type': str, 'default': 'strategies_deploy_data/spb-m-1/26-03/'}
#     }

# %%
deploy_data_file = _ROOT + 'Strategies/Sparsity_strategy/deploy_data_spb-m-1.py'

# %%
# !python {deploy_data_file} --instrument frm1 --top_k {_TOP_K} --fees {_FEES} --train_days {_TRAIN_DAYS} --cluster_size {_CLUSTER_SIZE} --directory_path {DIR_PATH}
# Out:
# == Loading arguments ===========================
#
#   ____       _____              _
#  |  _ \ _   |_   _|__  _ __ ___| |__
#  | |_) | | | || |/ _ \| '__/ __| '_ \
#  |  __/| |_| || | (_) | | | (__| | | |
#  |_|    \__, ||_|\___/|_|  \___|_| |_|
#         |___/
#
#
# == NVIDIA GPU STATUS ===========================
#   Device Name: NVIDIA RTX A4000
#   CUDA Version: 12.4
#   Stream multiprocessors: 48
#   Compute Capability: 8.6
#
#   Memory Usage:
#     Total: 15.99 GB
#     Used:  1.10 GB (6.9%)
#     Free:  14.89 GB
# frm1
# 200
# 0.05
# 5
# 5
# strategies_deploy_data/spb-fr-m-1/2025-05-05/
#
# ------------------------------------------------------------
# Loading file: W:/strategies_deploy_data/spb-fr-m-1/2025-05-05/backtest_obt_frm1.parquet
#
# ------------------------------------------------------------
#
# == Data preprocessing ==========================
#
# ------------------------------------------------------------
#
# == Loading cached returns... ===================
#
# ------------------------------------------------------------
#
# == features bool comparison -> MDXs ============
# Estimated memory usage: 0.03759765625 MB
#
# == Sorting combinations ========================
#    -> fit on points with shape (200, 7)
#                x1        x2        x3        x4   x5         x6  objective
# cluster
# 0        1.000000  6.000000  0.000000  4.000000  0.0  44.000000   2.453962
# 1        1.000000  2.795699  1.752688  3.032258  0.0  74.795699   2.367272
# 2        6.500000  1.000000  1.000000  6.500000  0.0  83.000000   2.259766
# 3        6.200000  5.700000  1.000000  0.000000  0.0  83.000000   2.568750
# 4        5.948718  5.846154  0.923077  5.730769  0.0  83.000000   2.685447
#              mean       std  count
# cluster
# 0        2.453962  0.091824      7
# 1        2.367272  0.191911     93
# 2        2.259766  0.000000     12
# 3        2.568750  0.238035     10
# 4        2.685447  0.425357     78
#
# == Run best clusters parameters in simulation ==
#    Running parameters 0 [0.16, 0.14, 0.04, 0.31, 1.0]
# objective func 0.06926509999378845
# current_pnl 0.23000000000000198
# sharp ratio 1.385301999875769
# overral_mean 0.0990000000000002
# count 18
# best params [0.16, 0.14, 0.04, 0.31, 1.0]
# best closing ['0.5', '0.4', '0.1', '10']
#    Running parameters 1 [0.16, 0.06, 0.06, 0.26, 1.0]
# objective func -0.04219261706410448
# current_pnl -0.29999999999999727
# sharp ratio -0.8438523412820896
# overral_mean 0.04909090909090934
# count 20
# best params [0.16, 0.14, 0.04, 0.31, 1.0]
# best closing ['0.5', '0.4', '0.1', '10']
#    Running parameters 2 [0.85, 0.0, 0.05, 0.75, 1.0]
# objective func -0.023811731520485005
# current_pnl -0.2699999999999976
# sharp ratio -0.8095988716964901
# overral_mean 0.06277777777777792
# count 34
# best params [0.16, 0.14, 0.04, 0.31, 1.0]
# best closing ['0.5', '0.4', '0.1', '10']
#    Running parameters 3 [0.7, 0.13, 0.05, 0.11, 1.0]
# objective func 0.12710471791119698
# current_pnl 0.7899999999999955
# sharp ratio 2.5420943582239395
# overral_mean 0.14818181818181778
# count 20
# best params [0.7, 0.13, 0.05, 0.11, 1.0]
# best closing ['0.75', '0.4', '0.15', '30']
#    Running parameters 4 [0.59, 0.14, 0.05, 0.48, 1.0]
# objective func 0.02418981455557892
# current_pnl 0.21999999999999909
# sharp ratio 0.6773148075562098
# overral_mean 0.09199999999999993
# count 28
# best params [0.7, 0.13, 0.05, 0.11, 1.0]
# best closing ['0.75', '0.4', '0.15', '30']
# Torch batch processing:   0%|          | 0/5632 [00:00<?, ?combs/s]
# Torch batch processing:   2%|▏         | 128/5632 [00:00<00:03, 1627.01combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:   5%|▍         | 256/5632 [00:00<00:01, 3121.52combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:   7%|▋         | 384/5632 [00:00<00:01, 4570.63combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:   9%|▉         | 512/5632 [00:00<00:00, 6022.45combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  11%|█▏        | 640/5632 [00:00<00:00, 7440.63combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  14%|█▎        | 768/5632 [00:00<00:00, 8826.05combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  16%|█▌        | 896/5632 [00:00<00:00, 10180.16combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  18%|█▊        | 1024/5632 [00:00<00:00, 11549.86combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  20%|██        | 1152/5632 [00:00<00:00, 12993.60combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  23%|██▎       | 1280/5632 [00:00<00:00, 14437.33combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  25%|██▌       | 1408/5632 [00:00<00:00, 15881.06combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  27%|██▋       | 1536/5632 [00:00<00:00, 17324.80combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  30%|██▉       | 1664/5632 [00:00<00:00, 18768.53combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  32%|███▏      | 1792/5632 [00:00<00:00, 20212.26combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  34%|███▍      | 1920/5632 [00:00<00:00, 21656.00combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  36%|███▋      | 2048/5632 [00:00<00:00, 23099.73combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  39%|███▊      | 2176/5632 [00:00<00:00, 24543.46combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  41%|████      | 2304/5632 [00:00<00:00, 25987.20combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  43%|████▎     | 2432/5632 [00:00<00:00, 27430.93combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  45%|████▌     | 2560/5632 [00:00<00:00, 28874.66combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  48%|████▊     | 2688/5632 [00:00<00:00, 30318.39combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  50%|█████     | 2816/5632 [00:00<00:00, 31762.13combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  52%|█████▏    | 2944/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  52%|█████▏    | 2944/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  55%|█████▍    | 3072/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  57%|█████▋    | 3200/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  59%|█████▉    | 3328/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  61%|██████▏   | 3456/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  64%|██████▎   | 3584/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  66%|██████▌   | 3712/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  68%|██████▊   | 3840/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  70%|███████   | 3968/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  73%|███████▎  | 4096/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  75%|███████▌  | 4224/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  77%|███████▋  | 4352/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  80%|███████▉  | 4480/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  82%|████████▏ | 4608/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  84%|████████▍ | 4736/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  86%|████████▋ | 4864/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  89%|████████▊ | 4992/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  91%|█████████ | 5120/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  93%|█████████▎| 5248/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  95%|█████████▌| 5376/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing:  98%|█████████▊| 5504/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing: 100%|██████████| 5632/5632 [00:00<00:00, 28405.48combs/s, mem=1.25 MB, gpu_temp=25]
# Torch batch processing: 100%|██████████| 5632/5632 [00:00<00:00, 49595.99combs/s, mem=1.25 MB, gpu_temp=25]

# %% [markdown]
# Best params
#
#     best params [0.7, 0.13, 0.05, 0.11, 1.0]
#     best closing ['0.75', '0.4', '0.15', '30']

# %% [markdown]
# #### Set config

# %%
import json
params, closing = json.load(open(_STORAGE + DIR_PATH + 'params.json', 'r')).values()
print(params, closing)

# %%
today = datetime.now()

algo_id = "spb-fr-m-2"
algo_caption = "SPB FR M2 v0.9"
exchange_id = "TRAYPORT"
package_name= "spbmark_strategy_v09"
instrument_id = ENUM.InstrumentID.FR_BASE_EEX
sequence_id = ENUM.SequenceID.M
product_id = f'10000104_{item_id+1}'#251 nov
brokers_list = [ENUM.Broker._EEX,
                    ENUM.Broker._GFI,
                    ENUM.Broker._ICAP,
                    ENUM.Broker._42FS,
                    ENUM.Broker._TFS,
                    ENUM.Broker._SPEC,
                    ENUM.Broker._GRFN]
#test env vars
# product_id = '10000104_254' # 254februar
# brokers_list = ['37', '38'] BRO 2, 3

max_position = 1
ql_max=0.7
hard_stop_loss = 1.0

thold_dense = 0.5
thold_sparse = 0.12
trd_gap = 0.04
bid_ask = 0.21
make_profit_margin = 0.25
stop_loss_margin = 0.3
loss_making_thold = 0.1
makeagg_ratio = 0.6
burnout_period = 5

lead_closing = False


config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": [instrument_id],
    "product_ids": [product_id],
    "broker_list": brokers_list,

    "trd_gap": trd_gap,
    "make_profit_margin": make_profit_margin,
    "loss_making_thold": loss_making_thold,
    "stop_loss_margin": stop_loss_margin,
    "makeagg_ratio_thold": makeagg_ratio,
    "burnout_period": burnout_period,
    "bid_ask": bid_ask,
    "max_position": max_position,
    'lead_closing':lead_closing,
    "thold_dense": thold_dense,
    "thold_sparse": thold_sparse,

    "hard_stop_loss": hard_stop_loss,
    "ql_max": ql_max

}

# %% [markdown]
# #### Limits

# %% [markdown]
# Change the `value` to desired limit and script will set unused products to 0.
#
# This will also set allowed price boundaries `_MAXIMUM_PRICE`, `_MINIMUM_PRICE`.

# %%
_MAXIMUM_PRICE = 200.0
_MINIMUM_PRICE = 10.0
limits = {
    "limits_per_sequence": {
        "maximum_purchase_price": {},
        "minimum_sales_price": {},
        "maximum_purchase_volume": {},
        "maximum_sales_volume": {}
    }
}
for product in ["10000100",
                "10000101", 
                "10000102", 
                "10000103", 
                "10000104", 
                "10000105", 
                "10000106"]:
    if product not in product_id:
        value = 0
    else:
        value = 3
    limits["limits_per_sequence"]["maximum_purchase_price"][product] = _MAXIMUM_PRICE
    limits["limits_per_sequence"]["minimum_sales_price"][product] = _MINIMUM_PRICE
    limits["limits_per_sequence"]["maximum_sales_volume"][product] = value
    limits["limits_per_sequence"]["maximum_purchase_volume"][product] = value

limits
# Out:
# {'limits_per_sequence': {'maximum_purchase_price': {'10000100': 200.0,
#    '10000101': 200.0,
#    '10000102': 200.0,
#    '10000103': 200.0,
#    '10000104': 200.0,
#    '10000105': 200.0,
#    '10000106': 200.0},
#   'minimum_sales_price': {'10000100': 10.0,
#    '10000101': 10.0,
#    '10000102': 10.0,
#    '10000103': 10.0,
#    '10000104': 10.0,
#    '10000105': 10.0,
#    '10000106': 10.0},
#   'maximum_purchase_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'maximum_sales_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0}}}

# %% [markdown]
# ### Create strategy

# %% [markdown]
# Check active strategies

# %%
cls.deactivate_strategy(algo_id)
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
print(cls.create_strategy(config))
# Out:
# {'product_ids': ['10000104_260'], 'broker_list': ['1441', '2', '4', '8', '7', '5', '3'], 'stop_loss_margin': 0.3, 'hard_stop_loss': 1.0, 'trd_gap': 0.04, 'make_profit_margin': 0.25, 'loss_making_thold': 0.1, 'ql_max': 0.7, 'makeagg_ratio_thold': 0.6, 'burnout_period': 5.0, 'bid_ask': 0.21, 'max_position': 1.0, 'lead_closing': False, 'thold_dense': 0.5, 'thold_sparse': 0.12, 'internal_number': 'spb-fr-m-2', 'caption': 'SPB FR M2 v0.9', 'exchange': 'TRAYPORT', 'active': False, 'instrument_ids': ['10001075'], 'package_name': 'spbmark_strategy_v09', 'halted': False, 'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'spb-fr-m-1',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 200.0,
#    '10000101': 200.0,
#    '10000102': 200.0,
#    '10000103': 200.0,
#    '10000104': 200.0,
#    '10000105': 200.0,
#    '10000106': 200.0},
#   'maximum_purchase_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'maximum_sales_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'minimum_sales_price': {'10000100': 10.0,
#    '10000101': 10.0,
#    '10000102': 10.0,
#    '10000103': 10.0,
#    '10000104': 10.0,
#    '10000105': 10.0,
#    '10000106': 10.0}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-05-05T06:53:20.285000'}

# %% [markdown]
# # Deactivate

# %%
cls.deactivate_strategy(algo_id)
# Out:
# {'product_ids': ['10000104_250'],
#  'broker_list': ['1441', '2', '4', '8', '7', '5', '3'],
#  'stop_loss_margin': 0.4,
#  'hard_stop_loss': 2.0,
#  'trd_gap': 0.09,
#  'make_profit_margin': 0.35,
#  'loss_making_thold': 0.1,
#  'ql_max': 0.7,
#  'makeagg_ratio_thold': 0.6,
#  'burnout_period': 2.0,
#  'bid_ask': 0.11,
#  'max_position': 1.0,
#  'lead_closing': False,
#  'thold_dense': 0.25,
#  'thold_sparse': 0.15,
#  'internal_number': 'spbmark_m_1',
#  'caption': 'SPB DE M1 v0.3',
#  'exchange': 'TRAYPORT',
#  'active': False,
#  'instrument_ids': ['10641710'],
#  'package_name': 'spbmark_strategy',
#  'halted': False,
#  'halt_reason': ''}
