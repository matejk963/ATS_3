# %%
from datetime import datetime, timedelta
import os
import numpy as np
import pandas as pd

import Strategies.Autotrader.enumerate as ENUM
from Utilities.Storage import get_curr_storage_path
from Strategies.Autotrader.TP_api import TP_api

# %% [markdown]
# ### Enviroment

# %%
ENV = 'prod'
cls = TP_api(ENV)
cls.token
# Out:
# 'a491b1b9-bf1a-47b9-b5a9-bc9df0c10efd'

# %% [markdown]
# ### Strategy config

# %% [markdown]
# #### Calculate product id for desired month product

# %%
month_item_id_to_month = lambda x: (x-241)%12+1

# %%
def month_to_item_id(month):
    return 241 + (month - 1) + 12 * ((256 - 241) // 12)

# %%
from SynthSpread.spreadviewer_class import SpreadSingle
today = datetime.now().date() + timedelta(days=1)
dates = pd.date_range(today, today, freq='B')
spread_class = SpreadSingle(['de'], ['m'], [2], [], ['eex'])
product_date = spread_class.product_dates(dates, 2, tn_bool=True)
item_id = month_to_item_id(product_date[0][0].month)

# %%
_STORAGE = get_curr_storage_path()
DIR_PATH  = 'strategies_deploy_data/spb-de-m-2/' + str(today) + '/'
try:
    os.makedirs(_STORAGE + DIR_PATH)
except FileExistsError:
    print(_STORAGE + DIR_PATH, 'already exists')

# %% [markdown]
# Calibration result
#
#     5_0.12_500_15
#     clustersize = 5
#     gap = 0.12
#     top_k = 500
#     train days = 15

# %%
_CLUSTER_SIZE = 5
_FEES = 0.12
_TOP_K = 500
_TRAIN_DAYS = 15

# %%
today = datetime.now().date() + timedelta(days=1)
delta = np.busday_offset(today, -_TRAIN_DAYS)
_START_DATE = str(delta)
delta = np.busday_offset(today, -1)
_END_DATE = str(delta)
print(_START_DATE, _END_DATE)
# Out:
# 2025-04-21 2025-05-09

# %%
_ROOT = os.getcwd().split('Strategies')[0]
reg_data_file = _ROOT + 'Strategies/Sparsity_strategy/data_factory_reg.py'

# %%
reg_data_file
# Out:
# 'c:\\Users\\algouser\\Documents\\GitHub\\EnergyTrading\\Python\\Strategies/Sparsity_strategy/data_factory_reg.py'

# %%
# !python {reg_data_file} --instrument dem2 --start_date {_START_DATE} --end_date {_END_DATE} --directory_path {DIR_PATH}
# Out:
# Dates out [datetime.datetime(2024, 1, 1, 0, 0), datetime.datetime(2024, 1, 11, 0, 0), datetime.datetime(2024, 1, 12, 0, 0), datetime.datetime(2024, 1, 15, 0, 0), datetime.datetime(2024, 1, 16, 0, 0), datetime.datetime(2024, 1, 17, 0, 0), datetime.datetime(2024, 1, 18, 0, 0), datetime.datetime(2024, 1, 19, 0, 0), datetime.datetime(2024, 1, 22, 0, 0), datetime.datetime(2024, 1, 23, 0, 0), datetime.datetime(2024, 3, 13, 0, 0), datetime.datetime(2024, 3, 14, 0, 0), datetime.datetime(2024, 3, 15, 0, 0), datetime.datetime(2024, 3, 18, 0, 0), datetime.datetime(2024, 3, 29, 0, 0), datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 4, 9, 0, 0), datetime.datetime(2024, 4, 10, 0, 0), datetime.datetime(2024, 5, 1, 0, 0), datetime.datetime(2024, 5, 22, 0, 0), datetime.datetime(2024, 5, 23, 0, 0), datetime.datetime(2024, 5, 24, 0, 0), datetime.datetime(2024, 5, 27, 0, 0), datetime.datetime(2024, 6, 3, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 23, 0, 0), datetime.datetime(2025, 1, 29, 0, 0), datetime.datetime(2025, 2, 26, 0, 0), datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 2, 28, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 21, 0, 0), datetime.datetime(2025, 5, 1, 0, 0)]
# Connected to the database oracle
# Disconnected from the database oracle
# 25-04-22 Loading OrderBook 0...
# OrderBook 0 created in 4 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-23 Loading OrderBook 0...
# OrderBook 0 created in 6 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-24 Loading OrderBook 0...
# OrderBook 0 created in 8 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-25 Loading OrderBook 0...
# OrderBook 0 created in 9 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-28 Loading OrderBook 0...
# OrderBook 0 created in 4 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-29 Loading OrderBook 0...
# OrderBook 0 created in 10 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-04-30 Loading OrderBook 0...
# OrderBook 0 created in 4 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-02 Loading OrderBook 0...
# OrderBook 0 created in 9 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-05 Loading OrderBook 0...
# OrderBook 0 created in 3 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-06 Loading OrderBook 0...
# OrderBook 0 created in 5 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-07 Loading OrderBook 0...
# OrderBook 0 created in 4 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-08 Loading OrderBook 0...
# OrderBook 0 created in 7 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# Prepare trd reg data
# 25-05-09 Loading OrderBook 0...
# OrderBook 0 created in 8 sec
# Connected to the database oracle
# Disconnected from the database oracle
# Prepare data combined entry
# Deleting following trades
#
# Empty DataFrame
# Columns: [tradeid, price, volume, action, broker_id, own_trades]
# Index: []
#
#
# Prepare reg data mkt
# single positional indexer is out-of-bounds
# ['lvl_dist', 'trd_price', 'trd_gap', 'trd_side', 'last_trade_margin']
# C:\Users\algouser\Documents\GitHub\EnergyTrading\Python\Strategies\Sparse_momentum\ob_attributes.py:1192: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['last_trd_p'].ffill(inplace=True)

# %%
cache_returns_file = _ROOT + 'Strategies/Sparsity_strategy/test_cache_returns.py'

# %%
# !python {cache_returns_file} --instrument dem2 --directory_path {DIR_PATH}
# Out:
#    processing combination 0 / 20
#    processing combination 1 / 20
#    processing combination 2 / 20
#    processing combination 3 / 20
#    processing combination 4 / 20
#    processing combination 5 / 20
#    processing combination 6 / 20
#    processing combination 7 / 20
#    processing combination 8 / 20
#    processing combination 9 / 20
#    processing combination 10 / 20
#    processing combination 11 / 20
#    processing combination 12 / 20
#    processing combination 13 / 20
#    processing combination 14 / 20
#    processing combination 15 / 20
#    processing combination 16 / 20
#    processing combination 17 / 20
#    processing combination 18 / 20
#    processing combination 19 / 20
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:17<03:14, 17.70s/days]
# Processing:  17%|█▋        | 2/12 [00:22<01:42, 10.24s/days]
# Processing:  25%|██▌       | 3/12 [00:23<00:53,  5.90s/days]
# Processing:  33%|███▎      | 4/12 [00:26<00:37,  4.63s/days]
# Processing: 100%|██████████| 12/12 [00:26<00:00,  2.18s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:26, 18.80s/days]
# Processing:  17%|█▋        | 2/12 [00:23<01:44, 10.46s/days]
# Processing:  33%|███▎      | 4/12 [00:26<00:39,  4.95s/days]
# Processing: 100%|██████████| 12/12 [00:26<00:00,  2.23s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:33, 19.44s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:48, 10.82s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:40,  5.09s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.30s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:27, 18.86s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:49, 11.00s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:40,  5.09s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.29s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:32, 19.35s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:52, 11.23s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:41,  5.22s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.35s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:18, 18.00s/days]
# Processing:  17%|█▋        | 2/12 [00:22<01:43, 10.32s/days]
# Processing:  25%|██▌       | 3/12 [00:23<00:52,  5.83s/days]
# Processing:  33%|███▎      | 4/12 [00:26<00:36,  4.60s/days]
# Processing: 100%|██████████| 12/12 [00:26<00:00,  2.18s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:24, 18.63s/days]
# Processing:  17%|█▋        | 2/12 [00:23<01:46, 10.68s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:40,  5.05s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.26s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:30, 19.14s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:50, 11.01s/days]
# Processing:  25%|██▌       | 3/12 [00:24<00:54,  6.08s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:39,  4.99s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.33s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:30, 19.14s/days]
# Processing:  17%|█▋        | 2/12 [00:25<01:55, 11.51s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:42,  5.31s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.38s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:27, 18.88s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:52, 11.26s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:41,  5.22s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.34s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:17<03:16, 17.86s/days]
# Processing:  17%|█▋        | 2/12 [00:23<01:47, 10.76s/days]
# Processing:  33%|███▎      | 4/12 [00:26<00:40,  5.05s/days]
# Processing: 100%|██████████| 12/12 [00:26<00:00,  2.25s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:24, 18.58s/days]
# Processing:  17%|█▋        | 2/12 [00:23<01:47, 10.76s/days]
# Processing:  25%|██▌       | 3/12 [00:24<00:56,  6.25s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:39,  4.94s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.31s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:25, 18.71s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:51, 11.19s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:41,  5.23s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.33s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:30, 19.14s/days]
# Processing:  17%|█▋        | 2/12 [00:25<01:54, 11.49s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:42,  5.36s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.39s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:19<03:32, 19.32s/days]
# Processing:  17%|█▋        | 2/12 [00:25<01:55, 11.59s/days]
# Processing:  25%|██▌       | 3/12 [00:25<00:57,  6.41s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:41,  5.16s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.42s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:22, 18.43s/days]
# Processing:  17%|█▋        | 2/12 [00:23<01:45, 10.55s/days]
# Processing:  25%|██▌       | 3/12 [00:23<00:53,  5.91s/days]
# Processing:  33%|███▎      | 4/12 [00:26<00:38,  4.77s/days]
# Processing: 100%|██████████| 12/12 [00:26<00:00,  2.24s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:17<03:17, 17.94s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:49, 11.00s/days]
# Processing:  25%|██▌       | 3/12 [00:24<00:54,  6.04s/days]
# Processing:  33%|███▎      | 4/12 [00:27<00:38,  4.83s/days]
# Processing: 100%|██████████| 12/12 [00:27<00:00,  2.27s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:21, 18.33s/days]
# Processing:  17%|█▋        | 2/12 [00:24<01:53, 11.32s/days]
# Processing:  25%|██▌       | 3/12 [00:24<00:56,  6.25s/days]
# Processing:  33%|███▎      | 4/12 [00:28<00:40,  5.02s/days]
# Processing: 100%|██████████| 12/12 [00:28<00:00,  2.34s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:18<03:25, 18.70s/days]
# Processing:  17%|█▋        | 2/12 [00:25<01:55, 11.55s/days]
# Processing:  33%|███▎      | 4/12 [00:29<00:44,  5.51s/days]
# Processing: 100%|██████████| 12/12 [00:29<00:00,  2.42s/days]
#
# Processing:   0%|          | 0/12 [00:00<?, ?days/s]
# Processing:   8%|▊         | 1/12 [00:20<03:41, 20.11s/days]
# Processing:  17%|█▋        | 2/12 [00:26<02:01, 12.13s/days]
# Processing:  33%|███▎      | 4/12 [00:29<00:43,  5.42s/days]
# Processing: 100%|██████████| 12/12 [00:29<00:00,  2.46s/days]

# %% [markdown]
#         '--instrument': {'type': str, 'default': 'dem1'},
#         '--top_k': {'type': int, 'default': 1000},
#         '--fees': {'type': float, 'default': 0.12},
#         '--train_days': {'type': int, 'default': 5},
#         '--cluster_size': {'type': int, 'default': 10},
#         '--directory_path': {'type': str, 'default': 'strategies_deploy_data/spb-m-1/26-03/'}
#     }

# %%
deploy_data_file = _ROOT + 'Strategies/Sparsity_strategy/deploy_data_spb-m-1.py'

# %%
# !python {deploy_data_file} --instrument dem2 --top_k {_TOP_K} --fees {_FEES} --train_days {_TRAIN_DAYS} --cluster_size {_CLUSTER_SIZE} --directory_path {DIR_PATH}
# Out:
# == Loading arguments ===========================
#
#   ____       _____              _
#  |  _ \ _   |_   _|__  _ __ ___| |__
#  | |_) | | | || |/ _ \| '__/ __| '_ \
#  |  __/| |_| || | (_) | | | (__| | | |
#  |_|    \__, ||_|\___/|_|  \___|_| |_|
#         |___/
#
#
# == NVIDIA GPU STATUS ===========================
#   Device Name: NVIDIA RTX A4000
#   CUDA Version: 12.4
#   Stream multiprocessors: 48
#   Compute Capability: 8.6
#
#   Memory Usage:
#     Total: 15.99 GB
#     Used:  1.10 GB (6.9%)
#     Free:  14.89 GB
# dem2
# 500
# 0.12
# 15
# 5
# strategies_deploy_data/spb-de-m-2/2025-05-12/
#
# ------------------------------------------------------------
# Loading file: W:/strategies_deploy_data/spb-de-m-2/2025-05-12/backtest_obt_dem2.parquet
#
# ------------------------------------------------------------
#
# == Data preprocessing ==========================
#
# ------------------------------------------------------------
#
# == Loading cached returns... ===================
#
# ------------------------------------------------------------
#
# == features bool comparison -> MDXs ============
# Estimated memory usage: 0.03759765625 MB
#
# == Sorting combinations ========================
#    -> fit on points with shape (500, 7)
#                x1        x2        x3        x4   x5         x6  objective
# cluster
# 0        1.473684  1.921053  4.000000  5.578947  0.0  16.000000   1.989849
# 1        3.383117  3.984848  4.266234  3.751082  0.0  18.833333   2.398607
#              mean       std  count
# cluster
# 0        1.989849  0.281438     38
# 1        2.398607  0.603930    462
#
# == Run best clusters parameters in simulation ==
#    Running parameters 0 [0.18, 0.04, 0.08, 0.47, 1.0]
# objective func 0.1683907732268674
# current_pnl 2.420000000000013
# sharp ratio 15.828732683325537
# overral_mean 0.1295833333333336
# count 94
# best params [0.18, 0.04, 0.08, 0.47, 1.0]
# best closing ['0.25', '0.4', '0.1', '5']
#    Running parameters 1 [0.31, 0.09, 0.08, 0.3, 1.0]
# objective func 0.02622440902684256
# current_pnl 0.4700000000000135
# sharp ratio 2.3601968124158303
# overral_mean 0.08934782608695682
# count 90
# best params [0.18, 0.04, 0.08, 0.47, 1.0]
# best closing ['0.25', '0.4', '0.1', '5']
# Torch batch processing:   0%|          | 0/5632 [00:00<?, ?combs/s]
# Torch batch processing:   2%|▏         | 128/5632 [00:00<00:03, 1542.82combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:   5%|▍         | 256/5632 [00:00<00:01, 3012.95combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:   7%|▋         | 384/5632 [00:00<00:01, 4519.43combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:   9%|▉         | 512/5632 [00:00<00:00, 5887.24combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  11%|█▏        | 640/5632 [00:00<00:00, 7193.50combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  14%|█▎        | 768/5632 [00:00<00:00, 8632.20combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  16%|█▌        | 896/5632 [00:00<00:00, 9849.32combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  18%|█▊        | 1024/5632 [00:00<00:00, 11044.94combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  20%|██        | 1152/5632 [00:00<00:00, 12425.55combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  23%|██▎       | 1280/5632 [00:00<00:00, 13806.17combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  25%|██▌       | 1408/5632 [00:00<00:00, 15186.79combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  27%|██▋       | 1536/5632 [00:00<00:00, 16567.41combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  30%|██▉       | 1664/5632 [00:00<00:00, 17948.02combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  32%|███▏      | 1792/5632 [00:00<00:00, 19328.64combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  34%|███▍      | 1920/5632 [00:00<00:00, 20709.26combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  36%|███▋      | 2048/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  36%|███▋      | 2048/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  39%|███▊      | 2176/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  41%|████      | 2304/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  43%|████▎     | 2432/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  45%|████▌     | 2560/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  48%|████▊     | 2688/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  50%|█████     | 2816/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  52%|█████▏    | 2944/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  55%|█████▍    | 3072/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  57%|█████▋    | 3200/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  59%|█████▉    | 3328/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  61%|██████▏   | 3456/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  64%|██████▎   | 3584/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  66%|██████▌   | 3712/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  68%|██████▊   | 3840/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  70%|███████   | 3968/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  73%|███████▎  | 4096/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  75%|███████▌  | 4224/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  77%|███████▋  | 4352/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  80%|███████▉  | 4480/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  82%|████████▏ | 4608/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  84%|████████▍ | 4736/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  86%|████████▋ | 4864/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  89%|████████▊ | 4992/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  91%|█████████ | 5120/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  93%|█████████▎| 5248/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  95%|█████████▌| 5376/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing:  98%|█████████▊| 5504/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing: 100%|██████████| 5632/5632 [00:00<00:00, 19916.52combs/s, mem=5.26 MB, gpu_temp=30]
# Torch batch processing: 100%|██████████| 5632/5632 [00:00<00:00, 41927.11combs/s, mem=5.26 MB, gpu_temp=30]

# %% [markdown]
# Best params
#
#     best params [0.42, 0.12, 0.08, 0.33, 1.0]
#     best closing ['0.75', '0.4', '0.15', '15']

# %% [markdown]
# #### Set config

# %%
import json
params, closing = json.load(open(_STORAGE + DIR_PATH + 'params.json', 'r')).values()
print(params, closing)
# Out:
# [0.18, 0.04, 0.08, 0.47, 1.0] ['0.25', '0.4', '0.1', '5']

# %%
today = datetime.now()

algo_id = "spb-de-m-2"
algo_caption = "SPB DE M2 v0.9"
exchange_id = "TRAYPORT"
package_name= "spbmark_strategy_v09"
instrument_id = ENUM.InstrumentID.DE_BASE_EEX
sequence_id = ENUM.SequenceID.M
product_id = f'10000104_{item_id}'#251 nov
brokers_list = [ENUM.Broker._EEX,
                    ENUM.Broker._GFI,
                    ENUM.Broker._ICAP,
                    ENUM.Broker._42FS,
                    ENUM.Broker._TFS,
                    ENUM.Broker._SPEC,
                    ENUM.Broker._GRFN]
#test env vars
# product_id = '10000104_254' # 254februar
# brokers_list = ['37', '38'] BRO 2, 3

max_position = 1
ql_max=0.7
hard_stop_loss = 1.0

thold_dense = params[0]
thold_sparse = params[1]
trd_gap = params[2]
bid_ask = params[3]
make_profit_margin = closing[0]
stop_loss_margin = closing[1]
loss_making_thold = closing[2]
makeagg_ratio = 0.6
burnout_period = closing[3]

lead_closing = False


config = {
    "internal_number": algo_id,
    "caption": algo_caption,
    "exchange": exchange_id,
    "package_name": package_name,
    "instrument_ids": [instrument_id],
    "product_ids": [product_id],
    "broker_list": brokers_list,

    "trd_gap": trd_gap,
    "make_profit_margin": make_profit_margin,
    "loss_making_thold": loss_making_thold,
    "stop_loss_margin": stop_loss_margin,
    "makeagg_ratio_thold": makeagg_ratio,
    "burnout_period": burnout_period,
    "bid_ask": bid_ask,
    "max_position": max_position,
    'lead_closing':lead_closing,
    "thold_dense": thold_dense,
    "thold_sparse": thold_sparse,

    "hard_stop_loss": hard_stop_loss,
    "ql_max": ql_max

}

# %% [markdown]
# #### Limits

# %% [markdown]
# Change the `value` to desired limit and script will set unused products to 0.
#
# This will also set allowed price boundaries `_MAXIMUM_PRICE`, `_MINIMUM_PRICE`.

# %%
_MAXIMUM_PRICE = 200.0
_MINIMUM_PRICE = 10.0
limits = {
    "limits_per_sequence": {
        "maximum_purchase_price": {},
        "minimum_sales_price": {},
        "maximum_purchase_volume": {},
        "maximum_sales_volume": {}
    }
}
for product in ["10000100",
                "10000101", 
                "10000102", 
                "10000103", 
                "10000104", 
                "10000105", 
                "10000106"]:
    if product not in product_id:
        value = 0
    else:
        value = 3
    limits["limits_per_sequence"]["maximum_purchase_price"][product] = _MAXIMUM_PRICE
    limits["limits_per_sequence"]["minimum_sales_price"][product] = _MINIMUM_PRICE
    limits["limits_per_sequence"]["maximum_sales_volume"][product] = value
    limits["limits_per_sequence"]["maximum_purchase_volume"][product] = value

limits
# Out:
# {'limits_per_sequence': {'maximum_purchase_price': {'10000100': 200.0,
#    '10000101': 200.0,
#    '10000102': 200.0,
#    '10000103': 200.0,
#    '10000104': 200.0,
#    '10000105': 200.0,
#    '10000106': 200.0},
#   'minimum_sales_price': {'10000100': 10.0,
#    '10000101': 10.0,
#    '10000102': 10.0,
#    '10000103': 10.0,
#    '10000104': 10.0,
#    '10000105': 10.0,
#    '10000106': 10.0},
#   'maximum_purchase_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'maximum_sales_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0}}}

# %% [markdown]
# ### Create strategy

# %% [markdown]
# Check active strategies

# %%
cls.deactivate_strategy(algo_id)
cls.delete_strategy(algo_id)
# Out:
# <Response [200]>

# %%
print(cls.create_strategy(config))
# Out:
# {'product_ids': ['10000104_259'], 'broker_list': ['1441', '2', '4', '8', '7', '5', '3'], 'stop_loss_margin': 0.4, 'hard_stop_loss': 1.0, 'trd_gap': 0.08, 'make_profit_margin': 0.25, 'loss_making_thold': 0.1, 'ql_max': 0.7, 'makeagg_ratio_thold': 0.6, 'burnout_period': 5.0, 'bid_ask': 0.47, 'max_position': 1.0, 'lead_closing': False, 'thold_dense': 0.18, 'thold_sparse': 0.04, 'internal_number': 'spb-de-m-2', 'caption': 'SPB DE M2 v0.9', 'exchange': 'TRAYPORT', 'active': False, 'instrument_ids': ['10641710'], 'package_name': 'spbmark_strategy_v09', 'halted': False, 'halt_reason': ''}

# %%
result = cls.set_limits(limits, algo_id=algo_id)
result
# Out:
# {'strategy_id': 'spb-de-m-2',
#  'exchange_id': 'TRAYPORT',
#  'limits_per_sequence': {'maximum_purchase_price': {'10000100': 200.0,
#    '10000101': 200.0,
#    '10000102': 200.0,
#    '10000103': 200.0,
#    '10000104': 200.0,
#    '10000105': 200.0,
#    '10000106': 200.0},
#   'maximum_purchase_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'maximum_sales_volume': {'10000100': 0,
#    '10000101': 0,
#    '10000102': 0,
#    '10000103': 0,
#    '10000104': 3,
#    '10000105': 0,
#    '10000106': 0},
#   'minimum_sales_price': {'10000100': 10.0,
#    '10000101': 10.0,
#    '10000102': 10.0,
#    '10000103': 10.0,
#    '10000104': 10.0,
#    '10000105': 10.0,
#    '10000106': 10.0}},
#  'limits_per_sequence_item': {'maximum_purchase_price': {},
#   'maximum_purchase_volume': {},
#   'maximum_sales_volume': {},
#   'minimum_sales_price': {}},
#  'update_time': '2025-05-11T13:16:06.712000'}
